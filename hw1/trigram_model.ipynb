# %%
import sys
from collections import defaultdict
import math
import random
import os
import os.path
from collections import deque, Counter
"""
COMS W4705 - Natural Language Processing - Fall 2019
Homework 1 - Programming Component: Trigram Language Models
Yassine Benajiba
"""
# Out:
# '\nCOMS W4705 - Natural Language Processing - Fall 2019\nHomework 1 - Programming Component: Trigram Language Models\nYassine Benajiba\n'

# %%
def corpus_reader(corpusfile, lexicon=None): 
    with open(corpusfile,'r') as corpus: 
        for line in corpus: 
            if line.strip():
                sequence = line.lower().strip().split()
                if lexicon: 
                    yield [word if word in lexicon else "UNK" for word in sequence]
                else: 
                    yield sequence

def get_lexicon(corpus):
    word_counts = defaultdict(int)
    for sentence in corpus:
        for word in sentence: 
            word_counts[word] += 1
    return set(word for word in word_counts if word_counts[word] > 1)  



def get_ngrams(sequence, n):
    """
    COMPLETE THIS FUNCTION (PART 1)
    Given a sequence, this function should return a list of n-grams, where each n-gram is a Python tuple.
    This should work for arbitrary values of 1 <= n < len(sequence).
    """
    sequence = deque(sequence)
    if n>1:
        sequence.extendleft(['START']*(n-1))
    else:
        sequence.extendleft(['START'])
    sequence.extend(['STOP'])
    sequence = list(sequence)
    ngrams = []
    for seq in range(0,len(sequence)-(n-1)):
        ngrams.append(tuple(sequence[seq:seq+n]))
    return ngrams

# %%
class TrigramModel(object):
    
    def __init__(self, corpusfile):
    
        # Iterate through the corpus once to build a lexicon 
        generator = corpus_reader(corpusfile)
        self.lexicon = get_lexicon(generator)
        self.lexicon.add("UNK")
        self.lexicon.add("START")
        self.lexicon.add("STOP")
    
        # Now iterate through the corpus again and count ngrams
        generator = corpus_reader(corpusfile, self.lexicon)
        self.count_ngrams(generator)
    
    def count_ngrams(self, corpus):
        """
        COMPLETE THIS METHOD (PART 2)
        Given a corpus iterator, populate dictionaries of unigram, bigram,
        and trigram counts. 
        """
        self.unigramcounts = Counter()
        self.bigramcounts = Counter()
        self.trigramcounts = Counter()
        self.total_words = 0
        for ind, sentence in enumerate(corpus):
            if ind > 1000:
                break
#             print("sentence :", ind)
            self.unigramcounts+= Counter(get_ngrams(sentence,1))
            self.bigramcounts+= Counter(get_ngrams(sentence,2))
            self.trigramcounts+= Counter(get_ngrams(sentence,3))
        self.total_words+= sum(self.unigramcounts.values())
        return self.unigramcounts, self.bigramcounts, self.trigramcounts, self.total_words
    
    def raw_trigram_probability(self,trigram):
        """
        COMPLETE THIS METHOD (PART 3)
        Returns the raw (unsmoothed) trigram probability
        """
        print("trigram got is",trigram)
        try:
            return round(self.trigramcounts[trigram] / self.bigramcounts[trigram[0:2]],2)
        except Exception as e:
            return 0
        
    def raw_bigram_probability(self, bigram):
        """
        COMPLETE THIS METHOD (PART 3)
        Returns the raw (unsmoothed) bigram probability
        """
        try:
            return round(self.bigramcounts[bigram]/self.unigramcounts[bigram[0]],2) #no backing off to unigram probability
        except Exception as e:
            return 0
        
    def raw_unigram_probability(self, unigram):
        """
        COMPLETE THIS METHOD (PART 3)
        Returns the raw (unsmoothed) unigram probability.
        """
        #hint: recomputing the denominator every time the method is called
        # can be slow! You might want to compute the total number of words once, 
        # store in the TrigramModel instance, and then re-use it.  
        try:
            return round(self.unigramcounts[unigram]/self.total_words,2)
        except Exception as e:
            return 0

    def generate_sentence(self,t=20): 
        """
        COMPLETE THIS METHOD (OPTIONAL)
        Generate a random sentence from the trigram model. t specifies the
        max length, but the sentence may be shorter if STOP is reached.
        """
        return result            

    def smoothed_trigram_probability(self, trigram):
        """
        COMPLETE THIS METHOD (PART 4)
        Returns the smoothed trigram probability (using linear interpolation). 
        """
        lambda1 = 1
        lambda2 = 1/3.0
        lambda3 = 1/3.0
        return lambda1 * self.raw_trigram_probability(trigram) #+ lambda2 * self.raw_bigram_probability(trigram[0:2]) + lambda3 * self.raw_unigram_probability(trigram[0])
        
    def sentence_logprob(self, sentence):
        """
        COMPLETE THIS METHOD (PART 5)
        Returns the log probability of an entire sequence.
        """
        trigram = get_ngrams(sentence,3)
        print("CHECK TRIGRAM",trigram)
        sent_prob = 0
        for tri in trigram:
            try:
                sent_prob+= math.log2(self.smoothed_trigram_probability(tri))
            except ValueError:
                sent_prob+=0
        return sent_prob

    def perplexity(self, corpus):
        """
        COMPLETE THIS METHOD (PART 6) 
        Returns the log probability of an entire sequence.
        """
        sent_logprob = 0
        for ind, sentence in enumerate(corpus):
            if ind>100:
                break
            try:
                sent_logprob+=math.log2(self.sentence_logprob(sentence))
            except ValueError:
                sent_logprob+=0
        norm_sent_logprob = sent_logprob/self.total_words
        return 2**(-norm_sent_logprob)


def essay_scoring_experiment(training_file1, training_file2, testdir1, testdir2):

        model1 = TrigramModel(training_file1)
        model2 = TrigramModel(training_file2)

        total = 0
        correct = 0       
 
        for f in os.listdir(testdir1):
            pp = model1.perplexity(corpus_reader(os.path.join(testdir1, f), model1.lexicon))
            # .. 
    
        for f in os.listdir(testdir2):
            pp = model2.perplexity(corpus_reader(os.path.join(testdir2, f), model2.lexicon))
            # .. 
        
        return 0.0

# %%
if __name__ == "__main__":

#     model = TrigramModel(sys.argv[1]) 
    model = TrigramModel("hw1_data/brown_train.txt")

    print(model.perplexity(corpus_reader("hw1_data/brown_train.txt",model.lexicon)))
    
#     print(model.unigramcounts)
#     print(model.unigramcounts[('the',)])
#     print(model.raw_unigram_probability(['the',]))

    # put test code here...
    # or run the script from the command line with 
    # $ python -i trigram_model.py [corpus_file]
    # >>> 
    #
    # you can then call methods on the model instance in the interactive 
    # Python prompt. 

#     dev_corpus = corpus_reader("hw1_data/brown_test.txt",model.lexicon)
#     print(model.perplexity(dev_corpus))

    # Testing perplexity: 
    # dev_corpus = corpus_reader(sys.argv[2], model.lexicon)
    # pp = model.perplexity(dev_corpus)
    # print(pp)


    # Essay scoring experiment: 
    # acc = essay_scoring_experiment('train_high.txt', 'train_low.txt", "test_high", "test_low")
    # print(acc)
# Out:
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'fulton'), ('the', 'fulton', 'county'), ('fulton', 'county', 'grand'), ('county', 'grand', 'jury'), ('grand', 'jury', 'said'), ('jury', 'said', 'friday'), ('said', 'friday', 'an'), ('friday', 'an', 'investigation'), ('an', 'investigation', 'of'), ('investigation', 'of', 'atlanta'), ('of', 'atlanta', "'s"), ('atlanta', "'s", 'recent'), ("'s", 'recent', 'primary'), ('recent', 'primary', 'election'), ('primary', 'election', 'produced'), ('election', 'produced', '``'), ('produced', '``', 'no'), ('``', 'no', 'evidence'), ('no', 'evidence', "''"), ('evidence', "''", 'that'), ("''", 'that', 'any'), ('that', 'any', 'irregularities'), ('any', 'irregularities', 'took'), ('irregularities', 'took', 'place'), ('took', 'place', '.'), ('place', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'fulton')
# trigram got is ('the', 'fulton', 'county')
# trigram got is ('fulton', 'county', 'grand')
# trigram got is ('county', 'grand', 'jury')
# trigram got is ('grand', 'jury', 'said')
# trigram got is ('jury', 'said', 'friday')
# trigram got is ('said', 'friday', 'an')
# trigram got is ('friday', 'an', 'investigation')
# trigram got is ('an', 'investigation', 'of')
# trigram got is ('investigation', 'of', 'atlanta')
# trigram got is ('of', 'atlanta', "'s")
# trigram got is ('atlanta', "'s", 'recent')
# trigram got is ("'s", 'recent', 'primary')
# trigram got is ('recent', 'primary', 'election')
# trigram got is ('primary', 'election', 'produced')
# trigram got is ('election', 'produced', '``')
# trigram got is ('produced', '``', 'no')
# trigram got is ('``', 'no', 'evidence')
# trigram got is ('no', 'evidence', "''")
# trigram got is ('evidence', "''", 'that')
# trigram got is ("''", 'that', 'any')
# trigram got is ('that', 'any', 'irregularities')
# trigram got is ('any', 'irregularities', 'took')
# trigram got is ('irregularities', 'took', 'place')
# trigram got is ('took', 'place', '.')
# trigram got is ('place', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jury'), ('the', 'jury', 'further'), ('jury', 'further', 'said'), ('further', 'said', 'in'), ('said', 'in', 'UNK'), ('in', 'UNK', 'UNK'), ('UNK', 'UNK', 'that'), ('UNK', 'that', 'the'), ('that', 'the', 'city'), ('the', 'city', 'executive'), ('city', 'executive', 'committee'), ('executive', 'committee', ','), ('committee', ',', 'which'), (',', 'which', 'had'), ('which', 'had', 'over-all'), ('had', 'over-all', 'charge'), ('over-all', 'charge', 'of'), ('charge', 'of', 'the'), ('of', 'the', 'election'), ('the', 'election', ','), ('election', ',', '``'), (',', '``', 'deserves'), ('``', 'deserves', 'the'), ('deserves', 'the', 'praise'), ('the', 'praise', 'and'), ('praise', 'and', 'thanks'), ('and', 'thanks', 'of'), ('thanks', 'of', 'the'), ('of', 'the', 'city'), ('the', 'city', 'of'), ('city', 'of', 'atlanta'), ('of', 'atlanta', "''"), ('atlanta', "''", 'for'), ("''", 'for', 'the'), ('for', 'the', 'manner'), ('the', 'manner', 'in'), ('manner', 'in', 'which'), ('in', 'which', 'the'), ('which', 'the', 'election'), ('the', 'election', 'was'), ('election', 'was', 'conducted'), ('was', 'conducted', '.'), ('conducted', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jury')
# trigram got is ('the', 'jury', 'further')
# trigram got is ('jury', 'further', 'said')
# trigram got is ('further', 'said', 'in')
# trigram got is ('said', 'in', 'UNK')
# trigram got is ('in', 'UNK', 'UNK')
# trigram got is ('UNK', 'UNK', 'that')
# trigram got is ('UNK', 'that', 'the')
# trigram got is ('that', 'the', 'city')
# trigram got is ('the', 'city', 'executive')
# trigram got is ('city', 'executive', 'committee')
# trigram got is ('executive', 'committee', ',')
# trigram got is ('committee', ',', 'which')
# trigram got is (',', 'which', 'had')
# trigram got is ('which', 'had', 'over-all')
# trigram got is ('had', 'over-all', 'charge')
# trigram got is ('over-all', 'charge', 'of')
# trigram got is ('charge', 'of', 'the')
# trigram got is ('of', 'the', 'election')
# trigram got is ('the', 'election', ',')
# trigram got is ('election', ',', '``')
# trigram got is (',', '``', 'deserves')
# trigram got is ('``', 'deserves', 'the')
# trigram got is ('deserves', 'the', 'praise')
# trigram got is ('the', 'praise', 'and')
# trigram got is ('praise', 'and', 'thanks')
# trigram got is ('and', 'thanks', 'of')
# trigram got is ('thanks', 'of', 'the')
# trigram got is ('of', 'the', 'city')
# trigram got is ('the', 'city', 'of')
# trigram got is ('city', 'of', 'atlanta')
# trigram got is ('of', 'atlanta', "''")
# trigram got is ('atlanta', "''", 'for')
# trigram got is ("''", 'for', 'the')
# trigram got is ('for', 'the', 'manner')
# trigram got is ('the', 'manner', 'in')
# trigram got is ('manner', 'in', 'which')
# trigram got is ('in', 'which', 'the')
# trigram got is ('which', 'the', 'election')
# trigram got is ('the', 'election', 'was')
# trigram got is ('election', 'was', 'conducted')
# trigram got is ('was', 'conducted', '.')
# trigram got is ('conducted', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'UNK'), ('the', 'UNK', 'term'), ('UNK', 'term', 'jury'), ('term', 'jury', 'had'), ('jury', 'had', 'been'), ('had', 'been', 'charged'), ('been', 'charged', 'by'), ('charged', 'by', 'fulton'), ('by', 'fulton', 'superior'), ('fulton', 'superior', 'court'), ('superior', 'court', 'judge'), ('court', 'judge', 'UNK'), ('judge', 'UNK', 'UNK'), ('UNK', 'UNK', 'to'), ('UNK', 'to', 'investigate'), ('to', 'investigate', 'reports'), ('investigate', 'reports', 'of'), ('reports', 'of', 'possible'), ('of', 'possible', '``'), ('possible', '``', 'irregularities'), ('``', 'irregularities', "''"), ('irregularities', "''", 'in'), ("''", 'in', 'the'), ('in', 'the', 'hard-fought'), ('the', 'hard-fought', 'primary'), ('hard-fought', 'primary', 'which'), ('primary', 'which', 'was'), ('which', 'was', 'won'), ('was', 'won', 'by'), ('won', 'by', 'UNK'), ('by', 'UNK', 'ivan'), ('UNK', 'ivan', 'allen'), ('ivan', 'allen', 'jr'), ('allen', 'jr', '&'), ('jr', '&', '.'), ('&', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'UNK')
# trigram got is ('the', 'UNK', 'term')
# trigram got is ('UNK', 'term', 'jury')
# trigram got is ('term', 'jury', 'had')
# trigram got is ('jury', 'had', 'been')
# trigram got is ('had', 'been', 'charged')
# trigram got is ('been', 'charged', 'by')
# trigram got is ('charged', 'by', 'fulton')
# trigram got is ('by', 'fulton', 'superior')
# trigram got is ('fulton', 'superior', 'court')
# trigram got is ('superior', 'court', 'judge')
# trigram got is ('court', 'judge', 'UNK')
# trigram got is ('judge', 'UNK', 'UNK')
# trigram got is ('UNK', 'UNK', 'to')
# trigram got is ('UNK', 'to', 'investigate')
# trigram got is ('to', 'investigate', 'reports')
# trigram got is ('investigate', 'reports', 'of')
# trigram got is ('reports', 'of', 'possible')
# trigram got is ('of', 'possible', '``')
# trigram got is ('possible', '``', 'irregularities')
# trigram got is ('``', 'irregularities', "''")
# trigram got is ('irregularities', "''", 'in')
# trigram got is ("''", 'in', 'the')
# trigram got is ('in', 'the', 'hard-fought')
# trigram got is ('the', 'hard-fought', 'primary')
# trigram got is ('hard-fought', 'primary', 'which')
# trigram got is ('primary', 'which', 'was')
# trigram got is ('which', 'was', 'won')
# trigram got is ('was', 'won', 'by')
# trigram got is ('won', 'by', 'UNK')
# trigram got is ('by', 'UNK', 'ivan')
# trigram got is ('UNK', 'ivan', 'allen')
# trigram got is ('ivan', 'allen', 'jr')
# trigram got is ('allen', 'jr', '&')
# trigram got is ('jr', '&', '.')
# trigram got is ('&', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', '``'), ('START', '``', 'only'), ('``', 'only', 'a'), ('only', 'a', 'relative'), ('a', 'relative', 'handful'), ('relative', 'handful', 'of'), ('handful', 'of', 'such'), ('of', 'such', 'reports'), ('such', 'reports', 'was'), ('reports', 'was', 'received'), ('was', 'received', "''"), ('received', "''", ','), ("''", ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', ','), ('said', ',', '``'), (',', '``', 'considering'), ('``', 'considering', 'the'), ('considering', 'the', 'widespread'), ('the', 'widespread', 'interest'), ('widespread', 'interest', 'in'), ('interest', 'in', 'the'), ('in', 'the', 'election'), ('the', 'election', ','), ('election', ',', 'the'), (',', 'the', 'number'), ('the', 'number', 'of'), ('number', 'of', 'voters'), ('of', 'voters', 'and'), ('voters', 'and', 'the'), ('and', 'the', 'size'), ('the', 'size', 'of'), ('size', 'of', 'this'), ('of', 'this', 'city'), ('this', 'city', "''"), ('city', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', '``')
# trigram got is ('START', '``', 'only')
# trigram got is ('``', 'only', 'a')
# trigram got is ('only', 'a', 'relative')
# trigram got is ('a', 'relative', 'handful')
# trigram got is ('relative', 'handful', 'of')
# trigram got is ('handful', 'of', 'such')
# trigram got is ('of', 'such', 'reports')
# trigram got is ('such', 'reports', 'was')
# trigram got is ('reports', 'was', 'received')
# trigram got is ('was', 'received', "''")
# trigram got is ('received', "''", ',')
# trigram got is ("''", ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', ',')
# trigram got is ('said', ',', '``')
# trigram got is (',', '``', 'considering')
# trigram got is ('``', 'considering', 'the')
# trigram got is ('considering', 'the', 'widespread')
# trigram got is ('the', 'widespread', 'interest')
# trigram got is ('widespread', 'interest', 'in')
# trigram got is ('interest', 'in', 'the')
# trigram got is ('in', 'the', 'election')
# trigram got is ('the', 'election', ',')
# trigram got is ('election', ',', 'the')
# trigram got is (',', 'the', 'number')
# trigram got is ('the', 'number', 'of')
# trigram got is ('number', 'of', 'voters')
# trigram got is ('of', 'voters', 'and')
# trigram got is ('voters', 'and', 'the')
# trigram got is ('and', 'the', 'size')
# trigram got is ('the', 'size', 'of')
# trigram got is ('size', 'of', 'this')
# trigram got is ('of', 'this', 'city')
# trigram got is ('this', 'city', "''")
# trigram got is ('city', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', 'it'), ('said', 'it', 'did'), ('it', 'did', 'find'), ('did', 'find', 'that'), ('find', 'that', 'many'), ('that', 'many', 'of'), ('many', 'of', 'georgia'), ('of', 'georgia', "'s"), ('georgia', "'s", 'registration'), ("'s", 'registration', 'and'), ('registration', 'and', 'election'), ('and', 'election', 'laws'), ('election', 'laws', '``'), ('laws', '``', 'are'), ('``', 'are', 'outmoded'), ('are', 'outmoded', 'or'), ('outmoded', 'or', 'inadequate'), ('or', 'inadequate', 'and'), ('inadequate', 'and', 'often'), ('and', 'often', 'ambiguous'), ('often', 'ambiguous', "''"), ('ambiguous', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', 'it')
# trigram got is ('said', 'it', 'did')
# trigram got is ('it', 'did', 'find')
# trigram got is ('did', 'find', 'that')
# trigram got is ('find', 'that', 'many')
# trigram got is ('that', 'many', 'of')
# trigram got is ('many', 'of', 'georgia')
# trigram got is ('of', 'georgia', "'s")
# trigram got is ('georgia', "'s", 'registration')
# trigram got is ("'s", 'registration', 'and')
# trigram got is ('registration', 'and', 'election')
# trigram got is ('and', 'election', 'laws')
# trigram got is ('election', 'laws', '``')
# trigram got is ('laws', '``', 'are')
# trigram got is ('``', 'are', 'outmoded')
# trigram got is ('are', 'outmoded', 'or')
# trigram got is ('outmoded', 'or', 'inadequate')
# trigram got is ('or', 'inadequate', 'and')
# trigram got is ('inadequate', 'and', 'often')
# trigram got is ('and', 'often', 'ambiguous')
# trigram got is ('often', 'ambiguous', "''")
# trigram got is ('ambiguous', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'it'), ('START', 'it', 'recommended'), ('it', 'recommended', 'that'), ('recommended', 'that', 'fulton'), ('that', 'fulton', 'legislators'), ('fulton', 'legislators', 'act'), ('legislators', 'act', '``'), ('act', '``', 'to'), ('``', 'to', 'have'), ('to', 'have', 'these'), ('have', 'these', 'laws'), ('these', 'laws', 'studied'), ('laws', 'studied', 'and'), ('studied', 'and', 'revised'), ('and', 'revised', 'to'), ('revised', 'to', 'the'), ('to', 'the', 'end'), ('the', 'end', 'of'), ('end', 'of', 'modernizing'), ('of', 'modernizing', 'and'), ('modernizing', 'and', 'improving'), ('and', 'improving', 'them'), ('improving', 'them', "''"), ('them', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'it')
# trigram got is ('START', 'it', 'recommended')
# trigram got is ('it', 'recommended', 'that')
# trigram got is ('recommended', 'that', 'fulton')
# trigram got is ('that', 'fulton', 'legislators')
# trigram got is ('fulton', 'legislators', 'act')
# trigram got is ('legislators', 'act', '``')
# trigram got is ('act', '``', 'to')
# trigram got is ('``', 'to', 'have')
# trigram got is ('to', 'have', 'these')
# trigram got is ('have', 'these', 'laws')
# trigram got is ('these', 'laws', 'studied')
# trigram got is ('laws', 'studied', 'and')
# trigram got is ('studied', 'and', 'revised')
# trigram got is ('and', 'revised', 'to')
# trigram got is ('revised', 'to', 'the')
# trigram got is ('to', 'the', 'end')
# trigram got is ('the', 'end', 'of')
# trigram got is ('end', 'of', 'modernizing')
# trigram got is ('of', 'modernizing', 'and')
# trigram got is ('modernizing', 'and', 'improving')
# trigram got is ('and', 'improving', 'them')
# trigram got is ('improving', 'them', "''")
# trigram got is ('them', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'grand'), ('the', 'grand', 'jury'), ('grand', 'jury', 'commented'), ('jury', 'commented', 'on'), ('commented', 'on', 'a'), ('on', 'a', 'number'), ('a', 'number', 'of'), ('number', 'of', 'other'), ('of', 'other', 'topics'), ('other', 'topics', ','), ('topics', ',', 'among'), (',', 'among', 'them'), ('among', 'them', 'the'), ('them', 'the', 'atlanta'), ('the', 'atlanta', 'and'), ('atlanta', 'and', 'fulton'), ('and', 'fulton', 'county'), ('fulton', 'county', 'purchasing'), ('county', 'purchasing', 'departments'), ('purchasing', 'departments', 'which'), ('departments', 'which', 'it'), ('which', 'it', 'said'), ('it', 'said', '``'), ('said', '``', 'are'), ('``', 'are', 'well'), ('are', 'well', 'operated'), ('well', 'operated', 'and'), ('operated', 'and', 'follow'), ('and', 'follow', 'generally'), ('follow', 'generally', 'accepted'), ('generally', 'accepted', 'practices'), ('accepted', 'practices', 'which'), ('practices', 'which', 'UNK'), ('which', 'UNK', 'to'), ('UNK', 'to', 'the'), ('to', 'the', 'best'), ('the', 'best', 'interest'), ('best', 'interest', 'of'), ('interest', 'of', 'both'), ('of', 'both', 'governments'), ('both', 'governments', "''"), ('governments', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'grand')
# trigram got is ('the', 'grand', 'jury')
# trigram got is ('grand', 'jury', 'commented')
# trigram got is ('jury', 'commented', 'on')
# trigram got is ('commented', 'on', 'a')
# trigram got is ('on', 'a', 'number')
# trigram got is ('a', 'number', 'of')
# trigram got is ('number', 'of', 'other')
# trigram got is ('of', 'other', 'topics')
# trigram got is ('other', 'topics', ',')
# trigram got is ('topics', ',', 'among')
# trigram got is (',', 'among', 'them')
# trigram got is ('among', 'them', 'the')
# trigram got is ('them', 'the', 'atlanta')
# trigram got is ('the', 'atlanta', 'and')
# trigram got is ('atlanta', 'and', 'fulton')
# trigram got is ('and', 'fulton', 'county')
# trigram got is ('fulton', 'county', 'purchasing')
# trigram got is ('county', 'purchasing', 'departments')
# trigram got is ('purchasing', 'departments', 'which')
# trigram got is ('departments', 'which', 'it')
# trigram got is ('which', 'it', 'said')
# trigram got is ('it', 'said', '``')
# trigram got is ('said', '``', 'are')
# trigram got is ('``', 'are', 'well')
# trigram got is ('are', 'well', 'operated')
# trigram got is ('well', 'operated', 'and')
# trigram got is ('operated', 'and', 'follow')
# trigram got is ('and', 'follow', 'generally')
# trigram got is ('follow', 'generally', 'accepted')
# trigram got is ('generally', 'accepted', 'practices')
# trigram got is ('accepted', 'practices', 'which')
# trigram got is ('practices', 'which', 'UNK')
# trigram got is ('which', 'UNK', 'to')
# trigram got is ('UNK', 'to', 'the')
# trigram got is ('to', 'the', 'best')
# trigram got is ('the', 'best', 'interest')
# trigram got is ('best', 'interest', 'of')
# trigram got is ('interest', 'of', 'both')
# trigram got is ('of', 'both', 'governments')
# trigram got is ('both', 'governments', "''")
# trigram got is ('governments', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'however'), ('START', 'however', ','), ('however', ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', 'it'), ('said', 'it', 'believes'), ('it', 'believes', '``'), ('believes', '``', 'these'), ('``', 'these', 'two'), ('these', 'two', 'offices'), ('two', 'offices', 'should'), ('offices', 'should', 'be'), ('should', 'be', 'combined'), ('be', 'combined', 'to'), ('combined', 'to', 'achieve'), ('to', 'achieve', 'greater'), ('achieve', 'greater', 'efficiency'), ('greater', 'efficiency', 'and'), ('efficiency', 'and', 'reduce'), ('and', 'reduce', 'the'), ('reduce', 'the', 'cost'), ('the', 'cost', 'of'), ('cost', 'of', 'administration'), ('of', 'administration', "''"), ('administration', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'however')
# trigram got is ('START', 'however', ',')
# trigram got is ('however', ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', 'it')
# trigram got is ('said', 'it', 'believes')
# trigram got is ('it', 'believes', '``')
# trigram got is ('believes', '``', 'these')
# trigram got is ('``', 'these', 'two')
# trigram got is ('these', 'two', 'offices')
# trigram got is ('two', 'offices', 'should')
# trigram got is ('offices', 'should', 'be')
# trigram got is ('should', 'be', 'combined')
# trigram got is ('be', 'combined', 'to')
# trigram got is ('combined', 'to', 'achieve')
# trigram got is ('to', 'achieve', 'greater')
# trigram got is ('achieve', 'greater', 'efficiency')
# trigram got is ('greater', 'efficiency', 'and')
# trigram got is ('efficiency', 'and', 'reduce')
# trigram got is ('and', 'reduce', 'the')
# trigram got is ('reduce', 'the', 'cost')
# trigram got is ('the', 'cost', 'of')
# trigram got is ('cost', 'of', 'administration')
# trigram got is ('of', 'administration', "''")
# trigram got is ('administration', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'city'), ('the', 'city', 'purchasing'), ('city', 'purchasing', 'department'), ('purchasing', 'department', ','), ('department', ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', ','), ('said', ',', '``'), (',', '``', 'is'), ('``', 'is', 'lacking'), ('is', 'lacking', 'in'), ('lacking', 'in', 'experienced'), ('in', 'experienced', 'clerical'), ('experienced', 'clerical', 'personnel'), ('clerical', 'personnel', 'as'), ('personnel', 'as', 'a'), ('as', 'a', 'result'), ('a', 'result', 'of'), ('result', 'of', 'city'), ('of', 'city', 'personnel'), ('city', 'personnel', 'policies'), ('personnel', 'policies', "''"), ('policies', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'city')
# trigram got is ('the', 'city', 'purchasing')
# trigram got is ('city', 'purchasing', 'department')
# trigram got is ('purchasing', 'department', ',')
# trigram got is ('department', ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', ',')
# trigram got is ('said', ',', '``')
# trigram got is (',', '``', 'is')
# trigram got is ('``', 'is', 'lacking')
# trigram got is ('is', 'lacking', 'in')
# trigram got is ('lacking', 'in', 'experienced')
# trigram got is ('in', 'experienced', 'clerical')
# trigram got is ('experienced', 'clerical', 'personnel')
# trigram got is ('clerical', 'personnel', 'as')
# trigram got is ('personnel', 'as', 'a')
# trigram got is ('as', 'a', 'result')
# trigram got is ('a', 'result', 'of')
# trigram got is ('result', 'of', 'city')
# trigram got is ('of', 'city', 'personnel')
# trigram got is ('city', 'personnel', 'policies')
# trigram got is ('personnel', 'policies', "''")
# trigram got is ('policies', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'it'), ('START', 'it', 'urged'), ('it', 'urged', 'that'), ('urged', 'that', 'the'), ('that', 'the', 'city'), ('the', 'city', '``'), ('city', '``', 'take'), ('``', 'take', 'steps'), ('take', 'steps', 'to'), ('steps', 'to', 'remedy'), ('to', 'remedy', "''"), ('remedy', "''", 'this'), ("''", 'this', 'problem'), ('this', 'problem', '.'), ('problem', '.', 'STOP')]
# trigram got is ('START', 'START', 'it')
# trigram got is ('START', 'it', 'urged')
# trigram got is ('it', 'urged', 'that')
# trigram got is ('urged', 'that', 'the')
# trigram got is ('that', 'the', 'city')
# trigram got is ('the', 'city', '``')
# trigram got is ('city', '``', 'take')
# trigram got is ('``', 'take', 'steps')
# trigram got is ('take', 'steps', 'to')
# trigram got is ('steps', 'to', 'remedy')
# trigram got is ('to', 'remedy', "''")
# trigram got is ('remedy', "''", 'this')
# trigram got is ("''", 'this', 'problem')
# trigram got is ('this', 'problem', '.')
# trigram got is ('problem', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'implementation'), ('START', 'implementation', 'of'), ('implementation', 'of', 'georgia'), ('of', 'georgia', "'s"), ('georgia', "'s", 'automobile'), ("'s", 'automobile', 'title'), ('automobile', 'title', 'law'), ('title', 'law', 'was'), ('law', 'was', 'also'), ('was', 'also', 'recommended'), ('also', 'recommended', 'by'), ('recommended', 'by', 'the'), ('by', 'the', 'outgoing'), ('the', 'outgoing', 'jury'), ('outgoing', 'jury', '.'), ('jury', '.', 'STOP')]
# trigram got is ('START', 'START', 'implementation')
# trigram got is ('START', 'implementation', 'of')
# trigram got is ('implementation', 'of', 'georgia')
# trigram got is ('of', 'georgia', "'s")
# trigram got is ('georgia', "'s", 'automobile')
# trigram got is ("'s", 'automobile', 'title')
# trigram got is ('automobile', 'title', 'law')
# trigram got is ('title', 'law', 'was')
# trigram got is ('law', 'was', 'also')
# trigram got is ('was', 'also', 'recommended')
# trigram got is ('also', 'recommended', 'by')
# trigram got is ('recommended', 'by', 'the')
# trigram got is ('by', 'the', 'outgoing')
# trigram got is ('the', 'outgoing', 'jury')
# trigram got is ('outgoing', 'jury', '.')
# trigram got is ('jury', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'it'), ('START', 'it', 'urged'), ('it', 'urged', 'that'), ('urged', 'that', 'the'), ('that', 'the', 'next'), ('the', 'next', 'legislature'), ('next', 'legislature', '``'), ('legislature', '``', 'provide'), ('``', 'provide', 'enabling'), ('provide', 'enabling', 'funds'), ('enabling', 'funds', 'and'), ('funds', 'and', 'UNK'), ('and', 'UNK', 'the'), ('UNK', 'the', 'effective'), ('the', 'effective', 'date'), ('effective', 'date', 'so'), ('date', 'so', 'that'), ('so', 'that', 'an'), ('that', 'an', 'orderly'), ('an', 'orderly', 'implementation'), ('orderly', 'implementation', 'of'), ('implementation', 'of', 'the'), ('of', 'the', 'law'), ('the', 'law', 'may'), ('law', 'may', 'be'), ('may', 'be', 'effected'), ('be', 'effected', "''"), ('effected', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'it')
# trigram got is ('START', 'it', 'urged')
# trigram got is ('it', 'urged', 'that')
# trigram got is ('urged', 'that', 'the')
# trigram got is ('that', 'the', 'next')
# trigram got is ('the', 'next', 'legislature')
# trigram got is ('next', 'legislature', '``')
# trigram got is ('legislature', '``', 'provide')
# trigram got is ('``', 'provide', 'enabling')
# trigram got is ('provide', 'enabling', 'funds')
# trigram got is ('enabling', 'funds', 'and')
# trigram got is ('funds', 'and', 'UNK')
# trigram got is ('and', 'UNK', 'the')
# trigram got is ('UNK', 'the', 'effective')
# trigram got is ('the', 'effective', 'date')
# trigram got is ('effective', 'date', 'so')
# trigram got is ('date', 'so', 'that')
# trigram got is ('so', 'that', 'an')
# trigram got is ('that', 'an', 'orderly')
# trigram got is ('an', 'orderly', 'implementation')
# trigram got is ('orderly', 'implementation', 'of')
# trigram got is ('implementation', 'of', 'the')
# trigram got is ('of', 'the', 'law')
# trigram got is ('the', 'law', 'may')
# trigram got is ('law', 'may', 'be')
# trigram got is ('may', 'be', 'effected')
# trigram got is ('be', 'effected', "''")
# trigram got is ('effected', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'grand'), ('the', 'grand', 'jury'), ('grand', 'jury', 'took'), ('jury', 'took', 'a'), ('took', 'a', 'swipe'), ('a', 'swipe', 'at'), ('swipe', 'at', 'the'), ('at', 'the', 'state'), ('the', 'state', 'welfare'), ('state', 'welfare', 'department'), ('welfare', 'department', "'s"), ('department', "'s", 'handling'), ("'s", 'handling', 'of'), ('handling', 'of', 'federal'), ('of', 'federal', 'funds'), ('federal', 'funds', 'granted'), ('funds', 'granted', 'for'), ('granted', 'for', 'child'), ('for', 'child', 'welfare'), ('child', 'welfare', 'services'), ('welfare', 'services', 'in'), ('services', 'in', 'foster'), ('in', 'foster', 'homes'), ('foster', 'homes', '.'), ('homes', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'grand')
# trigram got is ('the', 'grand', 'jury')
# trigram got is ('grand', 'jury', 'took')
# trigram got is ('jury', 'took', 'a')
# trigram got is ('took', 'a', 'swipe')
# trigram got is ('a', 'swipe', 'at')
# trigram got is ('swipe', 'at', 'the')
# trigram got is ('at', 'the', 'state')
# trigram got is ('the', 'state', 'welfare')
# trigram got is ('state', 'welfare', 'department')
# trigram got is ('welfare', 'department', "'s")
# trigram got is ('department', "'s", 'handling')
# trigram got is ("'s", 'handling', 'of')
# trigram got is ('handling', 'of', 'federal')
# trigram got is ('of', 'federal', 'funds')
# trigram got is ('federal', 'funds', 'granted')
# trigram got is ('funds', 'granted', 'for')
# trigram got is ('granted', 'for', 'child')
# trigram got is ('for', 'child', 'welfare')
# trigram got is ('child', 'welfare', 'services')
# trigram got is ('welfare', 'services', 'in')
# trigram got is ('services', 'in', 'foster')
# trigram got is ('in', 'foster', 'homes')
# trigram got is ('foster', 'homes', '.')
# trigram got is ('homes', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', '``'), ('START', '``', 'this'), ('``', 'this', 'is'), ('this', 'is', 'one'), ('is', 'one', 'of'), ('one', 'of', 'the'), ('of', 'the', 'major'), ('the', 'major', 'items'), ('major', 'items', 'in'), ('items', 'in', 'the'), ('in', 'the', 'fulton'), ('the', 'fulton', 'county'), ('fulton', 'county', 'general'), ('county', 'general', 'assistance'), ('general', 'assistance', 'program'), ('assistance', 'program', "''"), ('program', "''", ','), ("''", ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', ','), ('said', ',', 'but'), (',', 'but', 'the'), ('but', 'the', 'state'), ('the', 'state', 'welfare'), ('state', 'welfare', 'department'), ('welfare', 'department', '``'), ('department', '``', 'has'), ('``', 'has', 'seen'), ('has', 'seen', 'fit'), ('seen', 'fit', 'to'), ('fit', 'to', 'distribute'), ('to', 'distribute', 'these'), ('distribute', 'these', 'funds'), ('these', 'funds', 'through'), ('funds', 'through', 'the'), ('through', 'the', 'welfare'), ('the', 'welfare', 'departments'), ('welfare', 'departments', 'of'), ('departments', 'of', 'all'), ('of', 'all', 'the'), ('all', 'the', 'counties'), ('the', 'counties', 'in'), ('counties', 'in', 'the'), ('in', 'the', 'state'), ('the', 'state', 'with'), ('state', 'with', 'the'), ('with', 'the', 'exception'), ('the', 'exception', 'of'), ('exception', 'of', 'fulton'), ('of', 'fulton', 'county'), ('fulton', 'county', ','), ('county', ',', 'which'), (',', 'which', 'receives'), ('which', 'receives', 'none'), ('receives', 'none', 'of'), ('none', 'of', 'this'), ('of', 'this', 'money'), ('this', 'money', '.'), ('money', '.', 'STOP')]
# trigram got is ('START', 'START', '``')
# trigram got is ('START', '``', 'this')
# trigram got is ('``', 'this', 'is')
# trigram got is ('this', 'is', 'one')
# trigram got is ('is', 'one', 'of')
# trigram got is ('one', 'of', 'the')
# trigram got is ('of', 'the', 'major')
# trigram got is ('the', 'major', 'items')
# trigram got is ('major', 'items', 'in')
# trigram got is ('items', 'in', 'the')
# trigram got is ('in', 'the', 'fulton')
# trigram got is ('the', 'fulton', 'county')
# trigram got is ('fulton', 'county', 'general')
# trigram got is ('county', 'general', 'assistance')
# trigram got is ('general', 'assistance', 'program')
# trigram got is ('assistance', 'program', "''")
# trigram got is ('program', "''", ',')
# trigram got is ("''", ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', ',')
# trigram got is ('said', ',', 'but')
# trigram got is (',', 'but', 'the')
# trigram got is ('but', 'the', 'state')
# trigram got is ('the', 'state', 'welfare')
# trigram got is ('state', 'welfare', 'department')
# trigram got is ('welfare', 'department', '``')
# trigram got is ('department', '``', 'has')
# trigram got is ('``', 'has', 'seen')
# trigram got is ('has', 'seen', 'fit')
# trigram got is ('seen', 'fit', 'to')
# trigram got is ('fit', 'to', 'distribute')
# trigram got is ('to', 'distribute', 'these')
# trigram got is ('distribute', 'these', 'funds')
# trigram got is ('these', 'funds', 'through')
# trigram got is ('funds', 'through', 'the')
# trigram got is ('through', 'the', 'welfare')
# trigram got is ('the', 'welfare', 'departments')
# trigram got is ('welfare', 'departments', 'of')
# trigram got is ('departments', 'of', 'all')
# trigram got is ('of', 'all', 'the')
# trigram got is ('all', 'the', 'counties')
# trigram got is ('the', 'counties', 'in')
# trigram got is ('counties', 'in', 'the')
# trigram got is ('in', 'the', 'state')
# trigram got is ('the', 'state', 'with')
# trigram got is ('state', 'with', 'the')
# trigram got is ('with', 'the', 'exception')
# trigram got is ('the', 'exception', 'of')
# trigram got is ('exception', 'of', 'fulton')
# trigram got is ('of', 'fulton', 'county')
# trigram got is ('fulton', 'county', ',')
# trigram got is ('county', ',', 'which')
# trigram got is (',', 'which', 'receives')
# trigram got is ('which', 'receives', 'none')
# trigram got is ('receives', 'none', 'of')
# trigram got is ('none', 'of', 'this')
# trigram got is ('of', 'this', 'money')
# trigram got is ('this', 'money', '.')
# trigram got is ('money', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jurors'), ('the', 'jurors', 'said'), ('jurors', 'said', 'they'), ('said', 'they', 'realize'), ('they', 'realize', '``'), ('realize', '``', 'a'), ('``', 'a', 'proportionate'), ('a', 'proportionate', 'distribution'), ('proportionate', 'distribution', 'of'), ('distribution', 'of', 'these'), ('of', 'these', 'funds'), ('these', 'funds', 'might'), ('funds', 'might', 'UNK'), ('might', 'UNK', 'this'), ('UNK', 'this', 'program'), ('this', 'program', 'in'), ('program', 'in', 'our'), ('in', 'our', 'less'), ('our', 'less', 'populous'), ('less', 'populous', 'counties'), ('populous', 'counties', "''"), ('counties', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jurors')
# trigram got is ('the', 'jurors', 'said')
# trigram got is ('jurors', 'said', 'they')
# trigram got is ('said', 'they', 'realize')
# trigram got is ('they', 'realize', '``')
# trigram got is ('realize', '``', 'a')
# trigram got is ('``', 'a', 'proportionate')
# trigram got is ('a', 'proportionate', 'distribution')
# trigram got is ('proportionate', 'distribution', 'of')
# trigram got is ('distribution', 'of', 'these')
# trigram got is ('of', 'these', 'funds')
# trigram got is ('these', 'funds', 'might')
# trigram got is ('funds', 'might', 'UNK')
# trigram got is ('might', 'UNK', 'this')
# trigram got is ('UNK', 'this', 'program')
# trigram got is ('this', 'program', 'in')
# trigram got is ('program', 'in', 'our')
# trigram got is ('in', 'our', 'less')
# trigram got is ('our', 'less', 'populous')
# trigram got is ('less', 'populous', 'counties')
# trigram got is ('populous', 'counties', "''")
# trigram got is ('counties', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'nevertheless'), ('START', 'nevertheless', ','), ('nevertheless', ',', '``'), (',', '``', 'we'), ('``', 'we', 'feel'), ('we', 'feel', 'that'), ('feel', 'that', 'in'), ('that', 'in', 'the'), ('in', 'the', 'future'), ('the', 'future', 'fulton'), ('future', 'fulton', 'county'), ('fulton', 'county', 'should'), ('county', 'should', 'receive'), ('should', 'receive', 'some'), ('receive', 'some', 'portion'), ('some', 'portion', 'of'), ('portion', 'of', 'these'), ('of', 'these', 'available'), ('these', 'available', 'funds'), ('available', 'funds', "''"), ('funds', "''", ','), ("''", ',', 'the'), (',', 'the', 'jurors'), ('the', 'jurors', 'said'), ('jurors', 'said', '.'), ('said', '.', 'STOP')]
# trigram got is ('START', 'START', 'nevertheless')
# trigram got is ('START', 'nevertheless', ',')
# trigram got is ('nevertheless', ',', '``')
# trigram got is (',', '``', 'we')
# trigram got is ('``', 'we', 'feel')
# trigram got is ('we', 'feel', 'that')
# trigram got is ('feel', 'that', 'in')
# trigram got is ('that', 'in', 'the')
# trigram got is ('in', 'the', 'future')
# trigram got is ('the', 'future', 'fulton')
# trigram got is ('future', 'fulton', 'county')
# trigram got is ('fulton', 'county', 'should')
# trigram got is ('county', 'should', 'receive')
# trigram got is ('should', 'receive', 'some')
# trigram got is ('receive', 'some', 'portion')
# trigram got is ('some', 'portion', 'of')
# trigram got is ('portion', 'of', 'these')
# trigram got is ('of', 'these', 'available')
# trigram got is ('these', 'available', 'funds')
# trigram got is ('available', 'funds', "''")
# trigram got is ('funds', "''", ',')
# trigram got is ("''", ',', 'the')
# trigram got is (',', 'the', 'jurors')
# trigram got is ('the', 'jurors', 'said')
# trigram got is ('jurors', 'said', '.')
# trigram got is ('said', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', '``'), ('START', '``', 'failure'), ('``', 'failure', 'to'), ('failure', 'to', 'do'), ('to', 'do', 'this'), ('do', 'this', 'will'), ('this', 'will', 'continue'), ('will', 'continue', 'to'), ('continue', 'to', 'place'), ('to', 'place', 'a'), ('place', 'a', 'disproportionate'), ('a', 'disproportionate', 'burden'), ('disproportionate', 'burden', "''"), ('burden', "''", 'on'), ("''", 'on', 'fulton'), ('on', 'fulton', 'taxpayers'), ('fulton', 'taxpayers', '.'), ('taxpayers', '.', 'STOP')]
# trigram got is ('START', 'START', '``')
# trigram got is ('START', '``', 'failure')
# trigram got is ('``', 'failure', 'to')
# trigram got is ('failure', 'to', 'do')
# trigram got is ('to', 'do', 'this')
# trigram got is ('do', 'this', 'will')
# trigram got is ('this', 'will', 'continue')
# trigram got is ('will', 'continue', 'to')
# trigram got is ('continue', 'to', 'place')
# trigram got is ('to', 'place', 'a')
# trigram got is ('place', 'a', 'disproportionate')
# trigram got is ('a', 'disproportionate', 'burden')
# trigram got is ('disproportionate', 'burden', "''")
# trigram got is ('burden', "''", 'on')
# trigram got is ("''", 'on', 'fulton')
# trigram got is ('on', 'fulton', 'taxpayers')
# trigram got is ('fulton', 'taxpayers', '.')
# trigram got is ('taxpayers', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jury'), ('the', 'jury', 'also'), ('jury', 'also', 'commented'), ('also', 'commented', 'on'), ('commented', 'on', 'the'), ('on', 'the', 'fulton'), ('the', 'fulton', 'ordinary'), ('fulton', 'ordinary', "'s"), ('ordinary', "'s", 'court'), ("'s", 'court', 'which'), ('court', 'which', 'has'), ('which', 'has', 'been'), ('has', 'been', 'under'), ('been', 'under', 'fire'), ('under', 'fire', 'for'), ('fire', 'for', 'its'), ('for', 'its', 'practices'), ('its', 'practices', 'in'), ('practices', 'in', 'the'), ('in', 'the', 'appointment'), ('the', 'appointment', 'of'), ('appointment', 'of', 'UNK'), ('of', 'UNK', ','), ('UNK', ',', 'guardians'), (',', 'guardians', 'and'), ('guardians', 'and', 'administrators'), ('and', 'administrators', 'and'), ('administrators', 'and', 'the'), ('and', 'the', 'awarding'), ('the', 'awarding', 'of'), ('awarding', 'of', 'fees'), ('of', 'fees', 'and'), ('fees', 'and', 'compensation'), ('and', 'compensation', '.'), ('compensation', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jury')
# trigram got is ('the', 'jury', 'also')
# trigram got is ('jury', 'also', 'commented')
# trigram got is ('also', 'commented', 'on')
# trigram got is ('commented', 'on', 'the')
# trigram got is ('on', 'the', 'fulton')
# trigram got is ('the', 'fulton', 'ordinary')
# trigram got is ('fulton', 'ordinary', "'s")
# trigram got is ('ordinary', "'s", 'court')
# trigram got is ("'s", 'court', 'which')
# trigram got is ('court', 'which', 'has')
# trigram got is ('which', 'has', 'been')
# trigram got is ('has', 'been', 'under')
# trigram got is ('been', 'under', 'fire')
# trigram got is ('under', 'fire', 'for')
# trigram got is ('fire', 'for', 'its')
# trigram got is ('for', 'its', 'practices')
# trigram got is ('its', 'practices', 'in')
# trigram got is ('practices', 'in', 'the')
# trigram got is ('in', 'the', 'appointment')
# trigram got is ('the', 'appointment', 'of')
# trigram got is ('appointment', 'of', 'UNK')
# trigram got is ('of', 'UNK', ',')
# trigram got is ('UNK', ',', 'guardians')
# trigram got is (',', 'guardians', 'and')
# trigram got is ('guardians', 'and', 'administrators')
# trigram got is ('and', 'administrators', 'and')
# trigram got is ('administrators', 'and', 'the')
# trigram got is ('and', 'the', 'awarding')
# trigram got is ('the', 'awarding', 'of')
# trigram got is ('awarding', 'of', 'fees')
# trigram got is ('of', 'fees', 'and')
# trigram got is ('fees', 'and', 'compensation')
# trigram got is ('and', 'compensation', '.')
# trigram got is ('compensation', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', 'it'), ('said', 'it', 'found'), ('it', 'found', 'the'), ('found', 'the', 'court'), ('the', 'court', '``'), ('court', '``', 'has'), ('``', 'has', 'incorporated'), ('has', 'incorporated', 'into'), ('incorporated', 'into', 'its'), ('into', 'its', 'operating'), ('its', 'operating', 'procedures'), ('operating', 'procedures', 'the'), ('procedures', 'the', 'recommendations'), ('the', 'recommendations', "''"), ('recommendations', "''", 'of'), ("''", 'of', 'two'), ('of', 'two', 'previous'), ('two', 'previous', 'grand'), ('previous', 'grand', 'UNK'), ('grand', 'UNK', ','), ('UNK', ',', 'the'), (',', 'the', 'atlanta'), ('the', 'atlanta', 'bar'), ('atlanta', 'bar', 'association'), ('bar', 'association', 'and'), ('association', 'and', 'an'), ('and', 'an', 'interim'), ('an', 'interim', 'citizens'), ('interim', 'citizens', 'committee'), ('citizens', 'committee', '.'), ('committee', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', 'it')
# trigram got is ('said', 'it', 'found')
# trigram got is ('it', 'found', 'the')
# trigram got is ('found', 'the', 'court')
# trigram got is ('the', 'court', '``')
# trigram got is ('court', '``', 'has')
# trigram got is ('``', 'has', 'incorporated')
# trigram got is ('has', 'incorporated', 'into')
# trigram got is ('incorporated', 'into', 'its')
# trigram got is ('into', 'its', 'operating')
# trigram got is ('its', 'operating', 'procedures')
# trigram got is ('operating', 'procedures', 'the')
# trigram got is ('procedures', 'the', 'recommendations')
# trigram got is ('the', 'recommendations', "''")
# trigram got is ('recommendations', "''", 'of')
# trigram got is ("''", 'of', 'two')
# trigram got is ('of', 'two', 'previous')
# trigram got is ('two', 'previous', 'grand')
# trigram got is ('previous', 'grand', 'UNK')
# trigram got is ('grand', 'UNK', ',')
# trigram got is ('UNK', ',', 'the')
# trigram got is (',', 'the', 'atlanta')
# trigram got is ('the', 'atlanta', 'bar')
# trigram got is ('atlanta', 'bar', 'association')
# trigram got is ('bar', 'association', 'and')
# trigram got is ('association', 'and', 'an')
# trigram got is ('and', 'an', 'interim')
# trigram got is ('an', 'interim', 'citizens')
# trigram got is ('interim', 'citizens', 'committee')
# trigram got is ('citizens', 'committee', '.')
# trigram got is ('committee', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', '``'), ('START', '``', 'these'), ('``', 'these', 'actions'), ('these', 'actions', 'should'), ('actions', 'should', 'serve'), ('should', 'serve', 'to'), ('serve', 'to', 'protect'), ('to', 'protect', 'in'), ('protect', 'in', 'fact'), ('in', 'fact', 'and'), ('fact', 'and', 'in'), ('and', 'in', 'effect'), ('in', 'effect', 'the'), ('effect', 'the', 'court'), ('the', 'court', "'s"), ('court', "'s", 'wards'), ("'s", 'wards', 'from'), ('wards', 'from', 'undue'), ('from', 'undue', 'costs'), ('undue', 'costs', 'and'), ('costs', 'and', 'its'), ('and', 'its', 'appointed'), ('its', 'appointed', 'and'), ('appointed', 'and', 'elected'), ('and', 'elected', 'servants'), ('elected', 'servants', 'from'), ('servants', 'from', 'UNK'), ('from', 'UNK', 'criticisms'), ('UNK', 'criticisms', "''"), ('criticisms', "''", ','), ("''", ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'said'), ('jury', 'said', '.'), ('said', '.', 'STOP')]
# trigram got is ('START', 'START', '``')
# trigram got is ('START', '``', 'these')
# trigram got is ('``', 'these', 'actions')
# trigram got is ('these', 'actions', 'should')
# trigram got is ('actions', 'should', 'serve')
# trigram got is ('should', 'serve', 'to')
# trigram got is ('serve', 'to', 'protect')
# trigram got is ('to', 'protect', 'in')
# trigram got is ('protect', 'in', 'fact')
# trigram got is ('in', 'fact', 'and')
# trigram got is ('fact', 'and', 'in')
# trigram got is ('and', 'in', 'effect')
# trigram got is ('in', 'effect', 'the')
# trigram got is ('effect', 'the', 'court')
# trigram got is ('the', 'court', "'s")
# trigram got is ('court', "'s", 'wards')
# trigram got is ("'s", 'wards', 'from')
# trigram got is ('wards', 'from', 'undue')
# trigram got is ('from', 'undue', 'costs')
# trigram got is ('undue', 'costs', 'and')
# trigram got is ('costs', 'and', 'its')
# trigram got is ('and', 'its', 'appointed')
# trigram got is ('its', 'appointed', 'and')
# trigram got is ('appointed', 'and', 'elected')
# trigram got is ('and', 'elected', 'servants')
# trigram got is ('elected', 'servants', 'from')
# trigram got is ('servants', 'from', 'UNK')
# trigram got is ('from', 'UNK', 'criticisms')
# trigram got is ('UNK', 'criticisms', "''")
# trigram got is ('criticisms', "''", ',')
# trigram got is ("''", ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'said')
# trigram got is ('jury', 'said', '.')
# trigram got is ('said', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'regarding'), ('START', 'regarding', 'atlanta'), ('regarding', 'atlanta', "'s"), ('atlanta', "'s", 'new'), ("'s", 'new', 'multi-million-dollar'), ('new', 'multi-million-dollar', 'airport'), ('multi-million-dollar', 'airport', ','), ('airport', ',', 'the'), (',', 'the', 'jury'), ('the', 'jury', 'recommended'), ('jury', 'recommended', '``'), ('recommended', '``', 'that'), ('``', 'that', 'when'), ('that', 'when', 'the'), ('when', 'the', 'new'), ('the', 'new', 'management'), ('new', 'management', 'takes'), ('management', 'takes', 'charge'), ('takes', 'charge', 'jan'), ('charge', 'jan', '&'), ('jan', '&', '1'), ('&', '1', 'the'), ('1', 'the', 'airport'), ('the', 'airport', 'be'), ('airport', 'be', 'operated'), ('be', 'operated', 'in'), ('operated', 'in', 'a'), ('in', 'a', 'manner'), ('a', 'manner', 'that'), ('manner', 'that', 'will'), ('that', 'will', 'eliminate'), ('will', 'eliminate', 'political'), ('eliminate', 'political', 'influences'), ('political', 'influences', "''"), ('influences', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'regarding')
# trigram got is ('START', 'regarding', 'atlanta')
# trigram got is ('regarding', 'atlanta', "'s")
# trigram got is ('atlanta', "'s", 'new')
# trigram got is ("'s", 'new', 'multi-million-dollar')
# trigram got is ('new', 'multi-million-dollar', 'airport')
# trigram got is ('multi-million-dollar', 'airport', ',')
# trigram got is ('airport', ',', 'the')
# trigram got is (',', 'the', 'jury')
# trigram got is ('the', 'jury', 'recommended')
# trigram got is ('jury', 'recommended', '``')
# trigram got is ('recommended', '``', 'that')
# trigram got is ('``', 'that', 'when')
# trigram got is ('that', 'when', 'the')
# trigram got is ('when', 'the', 'new')
# trigram got is ('the', 'new', 'management')
# trigram got is ('new', 'management', 'takes')
# trigram got is ('management', 'takes', 'charge')
# trigram got is ('takes', 'charge', 'jan')
# trigram got is ('charge', 'jan', '&')
# trigram got is ('jan', '&', '1')
# trigram got is ('&', '1', 'the')
# trigram got is ('1', 'the', 'airport')
# trigram got is ('the', 'airport', 'be')
# trigram got is ('airport', 'be', 'operated')
# trigram got is ('be', 'operated', 'in')
# trigram got is ('operated', 'in', 'a')
# trigram got is ('in', 'a', 'manner')
# trigram got is ('a', 'manner', 'that')
# trigram got is ('manner', 'that', 'will')
# trigram got is ('that', 'will', 'eliminate')
# trigram got is ('will', 'eliminate', 'political')
# trigram got is ('eliminate', 'political', 'influences')
# trigram got is ('political', 'influences', "''")
# trigram got is ('influences', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'jury'), ('the', 'jury', 'did'), ('jury', 'did', 'not'), ('did', 'not', 'elaborate'), ('not', 'elaborate', ','), ('elaborate', ',', 'but'), (',', 'but', 'it'), ('but', 'it', 'added'), ('it', 'added', 'that'), ('added', 'that', '``'), ('that', '``', 'there'), ('``', 'there', 'should'), ('there', 'should', 'be'), ('should', 'be', 'periodic'), ('be', 'periodic', 'surveillance'), ('periodic', 'surveillance', 'of'), ('surveillance', 'of', 'the'), ('of', 'the', 'pricing'), ('the', 'pricing', 'practices'), ('pricing', 'practices', 'of'), ('practices', 'of', 'the'), ('of', 'the', 'concessionaires'), ('the', 'concessionaires', 'for'), ('concessionaires', 'for', 'the'), ('for', 'the', 'purpose'), ('the', 'purpose', 'of'), ('purpose', 'of', 'keeping'), ('of', 'keeping', 'the'), ('keeping', 'the', 'prices'), ('the', 'prices', 'reasonable'), ('prices', 'reasonable', "''"), ('reasonable', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'jury')
# trigram got is ('the', 'jury', 'did')
# trigram got is ('jury', 'did', 'not')
# trigram got is ('did', 'not', 'elaborate')
# trigram got is ('not', 'elaborate', ',')
# trigram got is ('elaborate', ',', 'but')
# trigram got is (',', 'but', 'it')
# trigram got is ('but', 'it', 'added')
# trigram got is ('it', 'added', 'that')
# trigram got is ('added', 'that', '``')
# trigram got is ('that', '``', 'there')
# trigram got is ('``', 'there', 'should')
# trigram got is ('there', 'should', 'be')
# trigram got is ('should', 'be', 'periodic')
# trigram got is ('be', 'periodic', 'surveillance')
# trigram got is ('periodic', 'surveillance', 'of')
# trigram got is ('surveillance', 'of', 'the')
# trigram got is ('of', 'the', 'pricing')
# trigram got is ('the', 'pricing', 'practices')
# trigram got is ('pricing', 'practices', 'of')
# trigram got is ('practices', 'of', 'the')
# trigram got is ('of', 'the', 'concessionaires')
# trigram got is ('the', 'concessionaires', 'for')
# trigram got is ('concessionaires', 'for', 'the')
# trigram got is ('for', 'the', 'purpose')
# trigram got is ('the', 'purpose', 'of')
# trigram got is ('purpose', 'of', 'keeping')
# trigram got is ('of', 'keeping', 'the')
# trigram got is ('keeping', 'the', 'prices')
# trigram got is ('the', 'prices', 'reasonable')
# trigram got is ('prices', 'reasonable', "''")
# trigram got is ('reasonable', "''", '.')
# ...
# trigram got is ('START', 'START', 'but')
# trigram got is ('START', 'but', 'questions')
# trigram got is ('but', 'questions', 'with')
# trigram got is ('questions', 'with', 'which')
# trigram got is ('with', 'which', 'committee')
# trigram got is ('which', 'committee', 'members')
# trigram got is ('committee', 'members', 'taunted')
# trigram got is ('members', 'taunted', 'bankers')
# trigram got is ('taunted', 'bankers', 'appearing')
# trigram got is ('bankers', 'appearing', 'as')
# trigram got is ('appearing', 'as', 'witnesses')
# trigram got is ('as', 'witnesses', 'left')
# trigram got is ('witnesses', 'left', 'little')
# trigram got is ('left', 'little', 'doubt')
# trigram got is ('little', 'doubt', 'that')
# trigram got is ('doubt', 'that', 'they')
# trigram got is ('that', 'they', 'will')
# trigram got is ('they', 'will', 'recommend')
# trigram got is ('will', 'recommend', 'passage')
# trigram got is ('recommend', 'passage', 'of')
# trigram got is ('passage', 'of', 'it')
# trigram got is ('of', 'it', '.')
# trigram got is ('it', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'daniel'), ('START', 'daniel', 'termed'), ('daniel', 'termed', '``'), ('termed', '``', 'extremely'), ('``', 'extremely', 'conservative'), ('extremely', 'conservative', "''"), ('conservative', "''", 'his'), ("''", 'his', 'estimate'), ('his', 'estimate', 'that'), ('estimate', 'that', 'it'), ('that', 'it', 'would'), ('it', 'would', 'produce'), ('would', 'produce', '17'), ('produce', '17', 'million'), ('17', 'million', 'dollars'), ('million', 'dollars', 'to'), ('dollars', 'to', 'help'), ('to', 'help', 'UNK'), ('help', 'UNK', 'an'), ('UNK', 'an', 'anticipated'), ('an', 'anticipated', 'deficit'), ('anticipated', 'deficit', 'of'), ('deficit', 'of', '63'), ('of', '63', 'million'), ('63', 'million', 'dollars'), ('million', 'dollars', 'at'), ('dollars', 'at', 'the'), ('at', 'the', 'end'), ('the', 'end', 'of'), ('end', 'of', 'the'), ('of', 'the', 'current'), ('the', 'current', 'fiscal'), ('current', 'fiscal', 'year'), ('fiscal', 'year', 'next'), ('year', 'next', 'aug'), ('next', 'aug', '&'), ('aug', '&', '31'), ('&', '31', '.'), ('31', '.', 'STOP')]
# trigram got is ('START', 'START', 'daniel')
# trigram got is ('START', 'daniel', 'termed')
# trigram got is ('daniel', 'termed', '``')
# trigram got is ('termed', '``', 'extremely')
# trigram got is ('``', 'extremely', 'conservative')
# trigram got is ('extremely', 'conservative', "''")
# trigram got is ('conservative', "''", 'his')
# trigram got is ("''", 'his', 'estimate')
# trigram got is ('his', 'estimate', 'that')
# trigram got is ('estimate', 'that', 'it')
# trigram got is ('that', 'it', 'would')
# trigram got is ('it', 'would', 'produce')
# trigram got is ('would', 'produce', '17')
# trigram got is ('produce', '17', 'million')
# trigram got is ('17', 'million', 'dollars')
# trigram got is ('million', 'dollars', 'to')
# trigram got is ('dollars', 'to', 'help')
# trigram got is ('to', 'help', 'UNK')
# trigram got is ('help', 'UNK', 'an')
# trigram got is ('UNK', 'an', 'anticipated')
# trigram got is ('an', 'anticipated', 'deficit')
# trigram got is ('anticipated', 'deficit', 'of')
# trigram got is ('deficit', 'of', '63')
# trigram got is ('of', '63', 'million')
# trigram got is ('63', 'million', 'dollars')
# trigram got is ('million', 'dollars', 'at')
# trigram got is ('dollars', 'at', 'the')
# trigram got is ('at', 'the', 'end')
# trigram got is ('the', 'end', 'of')
# trigram got is ('end', 'of', 'the')
# trigram got is ('of', 'the', 'current')
# trigram got is ('the', 'current', 'fiscal')
# trigram got is ('current', 'fiscal', 'year')
# trigram got is ('fiscal', 'year', 'next')
# trigram got is ('year', 'next', 'aug')
# trigram got is ('next', 'aug', '&')
# trigram got is ('aug', '&', '31')
# trigram got is ('&', '31', '.')
# trigram got is ('31', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'he'), ('START', 'he', 'told'), ('he', 'told', 'the'), ('told', 'the', 'committee'), ('the', 'committee', 'the'), ('committee', 'the', 'measure'), ('the', 'measure', 'would'), ('measure', 'would', 'merely'), ('would', 'merely', 'provide'), ('merely', 'provide', 'means'), ('provide', 'means', 'of'), ('means', 'of', 'enforcing'), ('of', 'enforcing', 'the'), ('enforcing', 'the', 'escheat'), ('the', 'escheat', 'law'), ('escheat', 'law', 'which'), ('law', 'which', 'has'), ('which', 'has', 'been'), ('has', 'been', 'on'), ('been', 'on', 'the'), ('on', 'the', 'books'), ('the', 'books', '``'), ('books', '``', 'since'), ('``', 'since', 'texas'), ('since', 'texas', 'was'), ('texas', 'was', 'a'), ('was', 'a', 'republic'), ('a', 'republic', "''"), ('republic', "''", '.'), ("''", '.', 'STOP')]
# trigram got is ('START', 'START', 'he')
# trigram got is ('START', 'he', 'told')
# trigram got is ('he', 'told', 'the')
# trigram got is ('told', 'the', 'committee')
# trigram got is ('the', 'committee', 'the')
# trigram got is ('committee', 'the', 'measure')
# trigram got is ('the', 'measure', 'would')
# trigram got is ('measure', 'would', 'merely')
# trigram got is ('would', 'merely', 'provide')
# trigram got is ('merely', 'provide', 'means')
# trigram got is ('provide', 'means', 'of')
# trigram got is ('means', 'of', 'enforcing')
# trigram got is ('of', 'enforcing', 'the')
# trigram got is ('enforcing', 'the', 'escheat')
# trigram got is ('the', 'escheat', 'law')
# trigram got is ('escheat', 'law', 'which')
# trigram got is ('law', 'which', 'has')
# trigram got is ('which', 'has', 'been')
# trigram got is ('has', 'been', 'on')
# trigram got is ('been', 'on', 'the')
# trigram got is ('on', 'the', 'books')
# trigram got is ('the', 'books', '``')
# trigram got is ('books', '``', 'since')
# trigram got is ('``', 'since', 'texas')
# trigram got is ('since', 'texas', 'was')
# trigram got is ('texas', 'was', 'a')
# trigram got is ('was', 'a', 'republic')
# trigram got is ('a', 'republic', "''")
# trigram got is ('republic', "''", '.')
# trigram got is ("''", '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'it'), ('START', 'it', 'permits'), ('it', 'permits', 'the'), ('permits', 'the', 'state'), ('the', 'state', 'to'), ('state', 'to', 'take'), ('to', 'take', 'over'), ('take', 'over', 'bank'), ('over', 'bank', 'accounts'), ('bank', 'accounts', ','), ('accounts', ',', 'stocks'), (',', 'stocks', 'and'), ('stocks', 'and', 'other'), ('and', 'other', 'personal'), ('other', 'personal', 'property'), ('personal', 'property', 'of'), ('property', 'of', 'persons'), ('of', 'persons', 'missing'), ('persons', 'missing', 'for'), ('missing', 'for', 'seven'), ('for', 'seven', 'years'), ('seven', 'years', 'or'), ('years', 'or', 'more'), ('or', 'more', '.'), ('more', '.', 'STOP')]
# trigram got is ('START', 'START', 'it')
# trigram got is ('START', 'it', 'permits')
# trigram got is ('it', 'permits', 'the')
# trigram got is ('permits', 'the', 'state')
# trigram got is ('the', 'state', 'to')
# trigram got is ('state', 'to', 'take')
# trigram got is ('to', 'take', 'over')
# trigram got is ('take', 'over', 'bank')
# trigram got is ('over', 'bank', 'accounts')
# trigram got is ('bank', 'accounts', ',')
# trigram got is ('accounts', ',', 'stocks')
# trigram got is (',', 'stocks', 'and')
# trigram got is ('stocks', 'and', 'other')
# trigram got is ('and', 'other', 'personal')
# trigram got is ('other', 'personal', 'property')
# trigram got is ('personal', 'property', 'of')
# trigram got is ('property', 'of', 'persons')
# trigram got is ('of', 'persons', 'missing')
# trigram got is ('persons', 'missing', 'for')
# trigram got is ('missing', 'for', 'seven')
# trigram got is ('for', 'seven', 'years')
# trigram got is ('seven', 'years', 'or')
# trigram got is ('years', 'or', 'more')
# trigram got is ('or', 'more', '.')
# trigram got is ('more', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'bill'), ('the', 'bill', ','), ('bill', ',', 'which'), (',', 'which', 'daniel'), ('which', 'daniel', 'said'), ('daniel', 'said', 'he'), ('said', 'he', 'drafted'), ('he', 'drafted', 'personally'), ('drafted', 'personally', ','), ('personally', ',', 'would'), (',', 'would', 'force'), ('would', 'force', 'banks'), ('force', 'banks', ','), ('banks', ',', 'insurance'), (',', 'insurance', 'firms'), ('insurance', 'firms', ','), ('firms', ',', 'pipeline'), (',', 'pipeline', 'companies'), ('pipeline', 'companies', 'and'), ('companies', 'and', 'other'), ('and', 'other', 'corporations'), ('other', 'corporations', 'to'), ('corporations', 'to', 'report'), ('to', 'report', 'such'), ('report', 'such', 'property'), ('such', 'property', 'to'), ('property', 'to', 'the'), ('to', 'the', 'state'), ('the', 'state', 'treasurer'), ('state', 'treasurer', '.'), ('treasurer', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'bill')
# trigram got is ('the', 'bill', ',')
# trigram got is ('bill', ',', 'which')
# trigram got is (',', 'which', 'daniel')
# trigram got is ('which', 'daniel', 'said')
# trigram got is ('daniel', 'said', 'he')
# trigram got is ('said', 'he', 'drafted')
# trigram got is ('he', 'drafted', 'personally')
# trigram got is ('drafted', 'personally', ',')
# trigram got is ('personally', ',', 'would')
# trigram got is (',', 'would', 'force')
# trigram got is ('would', 'force', 'banks')
# trigram got is ('force', 'banks', ',')
# trigram got is ('banks', ',', 'insurance')
# trigram got is (',', 'insurance', 'firms')
# trigram got is ('insurance', 'firms', ',')
# trigram got is ('firms', ',', 'pipeline')
# trigram got is (',', 'pipeline', 'companies')
# trigram got is ('pipeline', 'companies', 'and')
# trigram got is ('companies', 'and', 'other')
# trigram got is ('and', 'other', 'corporations')
# trigram got is ('other', 'corporations', 'to')
# trigram got is ('corporations', 'to', 'report')
# trigram got is ('to', 'report', 'such')
# trigram got is ('report', 'such', 'property')
# trigram got is ('such', 'property', 'to')
# trigram got is ('property', 'to', 'the')
# trigram got is ('to', 'the', 'state')
# trigram got is ('the', 'state', 'treasurer')
# trigram got is ('state', 'treasurer', '.')
# trigram got is ('treasurer', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'the'), ('START', 'the', 'escheat'), ('the', 'escheat', 'law'), ('escheat', 'law', 'can'), ('law', 'can', 'not'), ('can', 'not', 'be'), ('not', 'be', 'enforced'), ('be', 'enforced', 'now'), ('enforced', 'now', 'because'), ('now', 'because', 'it'), ('because', 'it', 'is'), ('it', 'is', 'almost'), ('is', 'almost', 'impossible'), ('almost', 'impossible', 'to'), ('impossible', 'to', 'locate'), ('to', 'locate', 'such'), ('locate', 'such', 'property'), ('such', 'property', ','), ('property', ',', 'daniel'), (',', 'daniel', 'declared'), ('daniel', 'declared', '.'), ('declared', '.', 'STOP')]
# trigram got is ('START', 'START', 'the')
# trigram got is ('START', 'the', 'escheat')
# trigram got is ('the', 'escheat', 'law')
# trigram got is ('escheat', 'law', 'can')
# trigram got is ('law', 'can', 'not')
# trigram got is ('can', 'not', 'be')
# trigram got is ('not', 'be', 'enforced')
# trigram got is ('be', 'enforced', 'now')
# trigram got is ('enforced', 'now', 'because')
# trigram got is ('now', 'because', 'it')
# trigram got is ('because', 'it', 'is')
# trigram got is ('it', 'is', 'almost')
# trigram got is ('is', 'almost', 'impossible')
# trigram got is ('almost', 'impossible', 'to')
# trigram got is ('impossible', 'to', 'locate')
# trigram got is ('to', 'locate', 'such')
# trigram got is ('locate', 'such', 'property')
# trigram got is ('such', 'property', ',')
# trigram got is ('property', ',', 'daniel')
# trigram got is (',', 'daniel', 'declared')
# trigram got is ('daniel', 'declared', '.')
# trigram got is ('declared', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', 'dewey'), ('START', 'dewey', 'lawrence'), ('dewey', 'lawrence', ','), ('lawrence', ',', 'a'), (',', 'a', 'tyler'), ('a', 'tyler', 'lawyer'), ('tyler', 'lawyer', 'representing'), ('lawyer', 'representing', 'the'), ('representing', 'the', 'texas'), ('the', 'texas', 'bankers'), ('texas', 'bankers', 'association'), ('bankers', 'association', ','), ('association', ',', 'sounded'), (',', 'sounded', 'the'), ('sounded', 'the', 'opposition'), ('the', 'opposition', 'keynote'), ('opposition', 'keynote', 'when'), ('keynote', 'when', 'he'), ('when', 'he', 'said'), ('he', 'said', 'it'), ('said', 'it', 'would'), ('it', 'would', 'force'), ('would', 'force', 'banks'), ('force', 'banks', 'to'), ('banks', 'to', 'violate'), ('to', 'violate', 'their'), ('violate', 'their', 'contractual'), ('their', 'contractual', 'obligations'), ('contractual', 'obligations', 'with'), ('obligations', 'with', 'UNK'), ('with', 'UNK', 'and'), ('UNK', 'and', 'undermine'), ('and', 'undermine', 'the'), ('undermine', 'the', 'confidence'), ('the', 'confidence', 'of'), ('confidence', 'of', 'bank'), ('of', 'bank', 'customers'), ('bank', 'customers', '.'), ('customers', '.', 'STOP')]
# trigram got is ('START', 'START', 'dewey')
# trigram got is ('START', 'dewey', 'lawrence')
# trigram got is ('dewey', 'lawrence', ',')
# trigram got is ('lawrence', ',', 'a')
# trigram got is (',', 'a', 'tyler')
# trigram got is ('a', 'tyler', 'lawyer')
# trigram got is ('tyler', 'lawyer', 'representing')
# trigram got is ('lawyer', 'representing', 'the')
# trigram got is ('representing', 'the', 'texas')
# trigram got is ('the', 'texas', 'bankers')
# trigram got is ('texas', 'bankers', 'association')
# trigram got is ('bankers', 'association', ',')
# trigram got is ('association', ',', 'sounded')
# trigram got is (',', 'sounded', 'the')
# trigram got is ('sounded', 'the', 'opposition')
# trigram got is ('the', 'opposition', 'keynote')
# trigram got is ('opposition', 'keynote', 'when')
# trigram got is ('keynote', 'when', 'he')
# trigram got is ('when', 'he', 'said')
# trigram got is ('he', 'said', 'it')
# trigram got is ('said', 'it', 'would')
# trigram got is ('it', 'would', 'force')
# trigram got is ('would', 'force', 'banks')
# trigram got is ('force', 'banks', 'to')
# trigram got is ('banks', 'to', 'violate')
# trigram got is ('to', 'violate', 'their')
# trigram got is ('violate', 'their', 'contractual')
# trigram got is ('their', 'contractual', 'obligations')
# trigram got is ('contractual', 'obligations', 'with')
# trigram got is ('obligations', 'with', 'UNK')
# trigram got is ('with', 'UNK', 'and')
# trigram got is ('UNK', 'and', 'undermine')
# trigram got is ('and', 'undermine', 'the')
# trigram got is ('undermine', 'the', 'confidence')
# trigram got is ('the', 'confidence', 'of')
# trigram got is ('confidence', 'of', 'bank')
# trigram got is ('of', 'bank', 'customers')
# trigram got is ('bank', 'customers', '.')
# trigram got is ('customers', '.', 'STOP')
# CHECK TRIGRAM [('START', 'START', '``'), ('START', '``', 'if'), ('``', 'if', 'you'), ('if', 'you', 'destroy'), ('you', 'destroy', 'confidence'), ('destroy', 'confidence', 'in'), ('confidence', 'in', 'banks'), ('in', 'banks', ','), ('banks', ',', 'you'), (',', 'you', 'do'), ('you', 'do', 'something'), ('do', 'something', 'to'), ('something', 'to', 'the'), ('to', 'the', 'economy'), ('the', 'economy', "''"), ('economy', "''", ','), ("''", ',', 'he'), (',', 'he', 'said'), ('he', 'said', '.'), ('said', '.', 'STOP')]
# trigram got is ('START', 'START', '``')
# trigram got is ('START', '``', 'if')
# trigram got is ('``', 'if', 'you')
# trigram got is ('if', 'you', 'destroy')
# trigram got is ('you', 'destroy', 'confidence')
# trigram got is ('destroy', 'confidence', 'in')
# trigram got is ('confidence', 'in', 'banks')
# trigram got is ('in', 'banks', ',')
# trigram got is ('banks', ',', 'you')
# trigram got is (',', 'you', 'do')
# trigram got is ('you', 'do', 'something')
# trigram got is ('do', 'something', 'to')
# trigram got is ('something', 'to', 'the')
# trigram got is ('to', 'the', 'economy')
# trigram got is ('the', 'economy', "''")
# trigram got is ('economy', "''", ',')
# trigram got is ("''", ',', 'he')
# trigram got is (',', 'he', 'said')
# trigram got is ('he', 'said', '.')
# trigram got is ('said', '.', 'STOP')
# 1.0

# %%
model.trigramcounts
# Out:
# Counter({('START', 'START', 'the'): 196,
#          ('START', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'county'): 3,
#          ('fulton', 'county', 'grand'): 1,
#          ('county', 'grand', 'jury'): 1,
#          ('grand', 'jury', 'said'): 1,
#          ('jury', 'said', 'friday'): 1,
#          ('said', 'friday', 'an'): 1,
#          ('friday', 'an', 'investigation'): 1,
#          ('an', 'investigation', 'of'): 1,
#          ('investigation', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', "'s"): 1,
#          ('atlanta', "'s", 'recent'): 1,
#          ("'s", 'recent', 'primary'): 1,
#          ('recent', 'primary', 'election'): 1,
#          ('primary', 'election', 'produced'): 1,
#          ('election', 'produced', '``'): 1,
#          ('produced', '``', 'no'): 1,
#          ('``', 'no', 'evidence'): 1,
#          ('no', 'evidence', "''"): 1,
#          ('evidence', "''", 'that'): 1,
#          ("''", 'that', 'any'): 1,
#          ('that', 'any', 'irregularities'): 1,
#          ('any', 'irregularities', 'took'): 1,
#          ('irregularities', 'took', 'place'): 1,
#          ('took', 'place', '.'): 1,
#          ('place', '.', 'STOP'): 1,
#          ('START', 'the', 'jury'): 6,
#          ('the', 'jury', 'further'): 1,
#          ('jury', 'further', 'said'): 1,
#          ('further', 'said', 'in'): 1,
#          ('said', 'in', 'UNK'): 1,
#          ('in', 'UNK', 'UNK'): 1,
#          ('UNK', 'UNK', 'that'): 1,
#          ('UNK', 'that', 'the'): 1,
#          ('that', 'the', 'city'): 5,
#          ('the', 'city', 'executive'): 1,
#          ('city', 'executive', 'committee'): 1,
#          ('executive', 'committee', ','): 1,
#          ('committee', ',', 'which'): 1,
#          (',', 'which', 'had'): 2,
#          ('which', 'had', 'over-all'): 1,
#          ('had', 'over-all', 'charge'): 1,
#          ('over-all', 'charge', 'of'): 1,
#          ('charge', 'of', 'the'): 1,
#          ('of', 'the', 'election'): 1,
#          ('the', 'election', ','): 2,
#          ('election', ',', '``'): 1,
#          (',', '``', 'deserves'): 1,
#          ('``', 'deserves', 'the'): 1,
#          ('deserves', 'the', 'praise'): 1,
#          ('the', 'praise', 'and'): 1,
#          ('praise', 'and', 'thanks'): 1,
#          ('and', 'thanks', 'of'): 1,
#          ('thanks', 'of', 'the'): 1,
#          ('of', 'the', 'city'): 5,
#          ('the', 'city', 'of'): 1,
#          ('city', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', "''"): 1,
#          ('atlanta', "''", 'for'): 1,
#          ("''", 'for', 'the'): 1,
#          ('for', 'the', 'manner'): 1,
#          ('the', 'manner', 'in'): 1,
#          ('manner', 'in', 'which'): 2,
#          ('in', 'which', 'the'): 3,
#          ('which', 'the', 'election'): 1,
#          ('the', 'election', 'was'): 2,
#          ('election', 'was', 'conducted'): 1,
#          ('was', 'conducted', '.'): 1,
#          ('conducted', '.', 'STOP'): 1,
#          ('START', 'the', 'UNK'): 3,
#          ('the', 'UNK', 'term'): 1,
#          ('UNK', 'term', 'jury'): 1,
#          ('term', 'jury', 'had'): 1,
#          ('jury', 'had', 'been'): 1,
#          ('had', 'been', 'charged'): 1,
#          ('been', 'charged', 'by'): 1,
#          ('charged', 'by', 'fulton'): 1,
#          ('by', 'fulton', 'superior'): 1,
#          ('fulton', 'superior', 'court'): 2,
#          ('superior', 'court', 'judge'): 2,
#          ('court', 'judge', 'UNK'): 1,
#          ('judge', 'UNK', 'UNK'): 1,
#          ('UNK', 'UNK', 'to'): 2,
#          ('UNK', 'to', 'investigate'): 1,
#          ('to', 'investigate', 'reports'): 1,
#          ('investigate', 'reports', 'of'): 1,
#          ('reports', 'of', 'possible'): 1,
#          ('of', 'possible', '``'): 1,
#          ('possible', '``', 'irregularities'): 1,
#          ('``', 'irregularities', "''"): 1,
#          ('irregularities', "''", 'in'): 1,
#          ("''", 'in', 'the'): 1,
#          ('in', 'the', 'hard-fought'): 1,
#          ('the', 'hard-fought', 'primary'): 1,
#          ('hard-fought', 'primary', 'which'): 1,
#          ('primary', 'which', 'was'): 1,
#          ('which', 'was', 'won'): 1,
#          ('was', 'won', 'by'): 1,
#          ('won', 'by', 'UNK'): 1,
#          ('by', 'UNK', 'ivan'): 1,
#          ('UNK', 'ivan', 'allen'): 1,
#          ('ivan', 'allen', 'jr'): 2,
#          ('allen', 'jr', '&'): 2,
#          ('jr', '&', '.'): 2,
#          ('&', '.', 'STOP'): 16,
#          ('START', 'START', '``'): 73,
#          ('START', '``', 'only'): 1,
#          ('``', 'only', 'a'): 1,
#          ('only', 'a', 'relative'): 1,
#          ('a', 'relative', 'handful'): 1,
#          ('relative', 'handful', 'of'): 1,
#          ('handful', 'of', 'such'): 1,
#          ('of', 'such', 'reports'): 1,
#          ('such', 'reports', 'was'): 1,
#          ('reports', 'was', 'received'): 1,
#          ('was', 'received', "''"): 1,
#          ('received', "''", ','): 1,
#          ("''", ',', 'the'): 12,
#          (',', 'the', 'jury'): 7,
#          ('the', 'jury', 'said'): 7,
#          ('jury', 'said', ','): 3,
#          ('said', ',', '``'): 14,
#          (',', '``', 'considering'): 1,
#          ('``', 'considering', 'the'): 1,
#          ('considering', 'the', 'widespread'): 1,
#          ('the', 'widespread', 'interest'): 1,
#          ('widespread', 'interest', 'in'): 1,
#          ('interest', 'in', 'the'): 1,
#          ('in', 'the', 'election'): 2,
#          ('election', ',', 'the'): 1,
#          (',', 'the', 'number'): 1,
#          ('the', 'number', 'of'): 3,
#          ('number', 'of', 'voters'): 1,
#          ('of', 'voters', 'and'): 1,
#          ('voters', 'and', 'the'): 1,
#          ('and', 'the', 'size'): 1,
#          ('the', 'size', 'of'): 1,
#          ('size', 'of', 'this'): 1,
#          ('of', 'this', 'city'): 1,
#          ('this', 'city', "''"): 1,
#          ('city', "''", '.'): 1,
#          ("''", '.', 'STOP'): 95,
#          ('jury', 'said', 'it'): 3,
#          ('said', 'it', 'did'): 1,
#          ('it', 'did', 'find'): 1,
#          ('did', 'find', 'that'): 1,
#          ('find', 'that', 'many'): 1,
#          ('that', 'many', 'of'): 1,
#          ('many', 'of', 'georgia'): 1,
#          ('of', 'georgia', "'s"): 4,
#          ('georgia', "'s", 'registration'): 1,
#          ("'s", 'registration', 'and'): 1,
#          ('registration', 'and', 'election'): 1,
#          ('and', 'election', 'laws'): 1,
#          ('election', 'laws', '``'): 1,
#          ('laws', '``', 'are'): 1,
#          ('``', 'are', 'outmoded'): 1,
#          ('are', 'outmoded', 'or'): 1,
#          ('outmoded', 'or', 'inadequate'): 1,
#          ('or', 'inadequate', 'and'): 1,
#          ('inadequate', 'and', 'often'): 1,
#          ('and', 'often', 'ambiguous'): 1,
#          ('often', 'ambiguous', "''"): 1,
#          ('ambiguous', "''", '.'): 1,
#          ('START', 'START', 'it'): 32,
#          ('START', 'it', 'recommended'): 1,
#          ('it', 'recommended', 'that'): 1,
#          ('recommended', 'that', 'fulton'): 1,
#          ('that', 'fulton', 'legislators'): 1,
#          ('fulton', 'legislators', 'act'): 1,
#          ('legislators', 'act', '``'): 1,
#          ('act', '``', 'to'): 1,
#          ('``', 'to', 'have'): 1,
#          ('to', 'have', 'these'): 1,
#          ('have', 'these', 'laws'): 1,
#          ('these', 'laws', 'studied'): 1,
#          ('laws', 'studied', 'and'): 1,
#          ('studied', 'and', 'revised'): 1,
#          ('and', 'revised', 'to'): 1,
#          ('revised', 'to', 'the'): 1,
#          ('to', 'the', 'end'): 1,
#          ('the', 'end', 'of'): 2,
#          ('end', 'of', 'modernizing'): 1,
#          ('of', 'modernizing', 'and'): 1,
#          ('modernizing', 'and', 'improving'): 1,
#          ('and', 'improving', 'them'): 1,
#          ('improving', 'them', "''"): 1,
#          ('them', "''", '.'): 3,
#          ('START', 'the', 'grand'): 2,
#          ('the', 'grand', 'jury'): 4,
#          ('grand', 'jury', 'commented'): 1,
#          ('jury', 'commented', 'on'): 1,
#          ('commented', 'on', 'a'): 1,
#          ('on', 'a', 'number'): 1,
#          ('a', 'number', 'of'): 5,
#          ('number', 'of', 'other'): 1,
#          ('of', 'other', 'topics'): 1,
#          ('other', 'topics', ','): 1,
#          ('topics', ',', 'among'): 1,
#          (',', 'among', 'them'): 1,
#          ('among', 'them', 'the'): 1,
#          ('them', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'and'): 1,
#          ('atlanta', 'and', 'fulton'): 1,
#          ('and', 'fulton', 'county'): 1,
#          ('fulton', 'county', 'purchasing'): 1,
#          ('county', 'purchasing', 'departments'): 1,
#          ('purchasing', 'departments', 'which'): 1,
#          ('departments', 'which', 'it'): 1,
#          ('which', 'it', 'said'): 1,
#          ('it', 'said', '``'): 1,
#          ('said', '``', 'are'): 1,
#          ('``', 'are', 'well'): 1,
#          ('are', 'well', 'operated'): 1,
#          ('well', 'operated', 'and'): 1,
#          ('operated', 'and', 'follow'): 1,
#          ('and', 'follow', 'generally'): 1,
#          ('follow', 'generally', 'accepted'): 1,
#          ('generally', 'accepted', 'practices'): 1,
#          ('accepted', 'practices', 'which'): 1,
#          ('practices', 'which', 'UNK'): 1,
#          ('which', 'UNK', 'to'): 1,
#          ('UNK', 'to', 'the'): 4,
#          ('to', 'the', 'best'): 1,
#          ('the', 'best', 'interest'): 1,
#          ('best', 'interest', 'of'): 1,
#          ('interest', 'of', 'both'): 1,
#          ('of', 'both', 'governments'): 1,
#          ('both', 'governments', "''"): 1,
#          ('governments', "''", '.'): 1,
#          ('START', 'START', 'however'): 1,
#          ('START', 'however', ','): 1,
#          ('however', ',', 'the'): 2,
#          ('said', 'it', 'believes'): 1,
#          ('it', 'believes', '``'): 1,
#          ('believes', '``', 'these'): 1,
#          ('``', 'these', 'two'): 1,
#          ('these', 'two', 'offices'): 1,
#          ('two', 'offices', 'should'): 1,
#          ('offices', 'should', 'be'): 1,
#          ('should', 'be', 'combined'): 1,
#          ('be', 'combined', 'to'): 1,
#          ('combined', 'to', 'achieve'): 1,
#          ('to', 'achieve', 'greater'): 1,
#          ('achieve', 'greater', 'efficiency'): 1,
#          ('greater', 'efficiency', 'and'): 1,
#          ('efficiency', 'and', 'reduce'): 1,
#          ('and', 'reduce', 'the'): 1,
#          ('reduce', 'the', 'cost'): 1,
#          ('the', 'cost', 'of'): 2,
#          ('cost', 'of', 'administration'): 1,
#          ('of', 'administration', "''"): 1,
#          ('administration', "''", '.'): 1,
#          ('START', 'the', 'city'): 5,
#          ('the', 'city', 'purchasing'): 1,
#          ('city', 'purchasing', 'department'): 1,
#          ('purchasing', 'department', ','): 1,
#          ('department', ',', 'the'): 2,
#          (',', '``', 'is'): 1,
#          ('``', 'is', 'lacking'): 1,
#          ('is', 'lacking', 'in'): 1,
#          ('lacking', 'in', 'experienced'): 1,
#          ('in', 'experienced', 'clerical'): 1,
#          ('experienced', 'clerical', 'personnel'): 1,
#          ('clerical', 'personnel', 'as'): 1,
#          ('personnel', 'as', 'a'): 1,
#          ('as', 'a', 'result'): 4,
#          ('a', 'result', 'of'): 2,
#          ('result', 'of', 'city'): 1,
#          ('of', 'city', 'personnel'): 1,
#          ('city', 'personnel', 'policies'): 1,
#          ('personnel', 'policies', "''"): 1,
#          ('policies', "''", '.'): 1,
#          ('START', 'it', 'urged'): 2,
#          ('it', 'urged', 'that'): 2,
#          ('urged', 'that', 'the'): 2,
#          ('the', 'city', '``'): 1,
#          ('city', '``', 'take'): 1,
#          ('``', 'take', 'steps'): 1,
#          ('take', 'steps', 'to'): 2,
#          ('steps', 'to', 'remedy'): 1,
#          ('to', 'remedy', "''"): 1,
#          ('remedy', "''", 'this'): 1,
#          ("''", 'this', 'problem'): 1,
#          ('this', 'problem', '.'): 1,
#          ('problem', '.', 'STOP'): 3,
#          ('START', 'START', 'implementation'): 1,
#          ('START', 'implementation', 'of'): 1,
#          ('implementation', 'of', 'georgia'): 1,
#          ('georgia', "'s", 'automobile'): 1,
#          ("'s", 'automobile', 'title'): 1,
#          ('automobile', 'title', 'law'): 1,
#          ('title', 'law', 'was'): 1,
#          ('law', 'was', 'also'): 1,
#          ('was', 'also', 'recommended'): 1,
#          ('also', 'recommended', 'by'): 1,
#          ('recommended', 'by', 'the'): 1,
#          ('by', 'the', 'outgoing'): 1,
#          ('the', 'outgoing', 'jury'): 1,
#          ('outgoing', 'jury', '.'): 1,
#          ('jury', '.', 'STOP'): 2,
#          ('that', 'the', 'next'): 2,
#          ('the', 'next', 'legislature'): 1,
#          ('next', 'legislature', '``'): 1,
#          ('legislature', '``', 'provide'): 1,
#          ('``', 'provide', 'enabling'): 1,
#          ('provide', 'enabling', 'funds'): 1,
#          ('enabling', 'funds', 'and'): 1,
#          ('funds', 'and', 'UNK'): 1,
#          ('and', 'UNK', 'the'): 1,
#          ('UNK', 'the', 'effective'): 1,
#          ('the', 'effective', 'date'): 1,
#          ('effective', 'date', 'so'): 1,
#          ('date', 'so', 'that'): 1,
#          ('so', 'that', 'an'): 1,
#          ('that', 'an', 'orderly'): 1,
#          ('an', 'orderly', 'implementation'): 1,
#          ('orderly', 'implementation', 'of'): 1,
#          ('implementation', 'of', 'the'): 1,
#          ('of', 'the', 'law'): 1,
#          ('the', 'law', 'may'): 1,
#          ('law', 'may', 'be'): 1,
#          ('may', 'be', 'effected'): 1,
#          ('be', 'effected', "''"): 1,
#          ('effected', "''", '.'): 1,
#          ('grand', 'jury', 'took'): 1,
#          ('jury', 'took', 'a'): 1,
#          ('took', 'a', 'swipe'): 1,
#          ('a', 'swipe', 'at'): 1,
#          ('swipe', 'at', 'the'): 1,
#          ('at', 'the', 'state'): 1,
#          ('the', 'state', 'welfare'): 2,
#          ('state', 'welfare', 'department'): 2,
#          ('welfare', 'department', "'s"): 1,
#          ('department', "'s", 'handling'): 1,
#          ("'s", 'handling', 'of'): 1,
#          ('handling', 'of', 'federal'): 1,
#          ('of', 'federal', 'funds'): 1,
#          ('federal', 'funds', 'granted'): 1,
#          ('funds', 'granted', 'for'): 1,
#          ('granted', 'for', 'child'): 1,
#          ('for', 'child', 'welfare'): 1,
#          ('child', 'welfare', 'services'): 1,
#          ('welfare', 'services', 'in'): 1,
#          ('services', 'in', 'foster'): 1,
#          ('in', 'foster', 'homes'): 1,
#          ('foster', 'homes', '.'): 1,
#          ('homes', '.', 'STOP'): 2,
#          ('START', '``', 'this'): 6,
#          ('``', 'this', 'is'): 5,
#          ('this', 'is', 'one'): 1,
#          ('is', 'one', 'of'): 3,
#          ('one', 'of', 'the'): 10,
#          ('of', 'the', 'major'): 1,
#          ('the', 'major', 'items'): 1,
#          ('major', 'items', 'in'): 1,
#          ('items', 'in', 'the'): 1,
#          ('in', 'the', 'fulton'): 1,
#          ('fulton', 'county', 'general'): 1,
#          ('county', 'general', 'assistance'): 1,
#          ('general', 'assistance', 'program'): 1,
#          ('assistance', 'program', "''"): 1,
#          ('program', "''", ','): 1,
#          ('said', ',', 'but'): 1,
#          (',', 'but', 'the'): 3,
#          ('but', 'the', 'state'): 1,
#          ('welfare', 'department', '``'): 1,
#          ('department', '``', 'has'): 1,
#          ('``', 'has', 'seen'): 1,
#          ('has', 'seen', 'fit'): 1,
#          ('seen', 'fit', 'to'): 1,
#          ('fit', 'to', 'distribute'): 1,
#          ('to', 'distribute', 'these'): 1,
#          ('distribute', 'these', 'funds'): 1,
#          ('these', 'funds', 'through'): 1,
#          ('funds', 'through', 'the'): 1,
#          ('through', 'the', 'welfare'): 1,
#          ('the', 'welfare', 'departments'): 1,
#          ('welfare', 'departments', 'of'): 1,
#          ('departments', 'of', 'all'): 1,
#          ('of', 'all', 'the'): 1,
#          ('all', 'the', 'counties'): 1,
#          ('the', 'counties', 'in'): 1,
#          ('counties', 'in', 'the'): 2,
#          ('in', 'the', 'state'): 9,
#          ('the', 'state', 'with'): 1,
#          ('state', 'with', 'the'): 1,
#          ('with', 'the', 'exception'): 1,
#          ('the', 'exception', 'of'): 1,
#          ('exception', 'of', 'fulton'): 1,
#          ('of', 'fulton', 'county'): 1,
#          ('fulton', 'county', ','): 1,
#          ('county', ',', 'which'): 1,
#          (',', 'which', 'receives'): 1,
#          ('which', 'receives', 'none'): 1,
#          ('receives', 'none', 'of'): 1,
#          ('none', 'of', 'this'): 1,
#          ('of', 'this', 'money'): 1,
#          ('this', 'money', '.'): 1,
#          ('money', '.', 'STOP'): 1,
#          ('START', 'the', 'jurors'): 1,
#          ('the', 'jurors', 'said'): 2,
#          ('jurors', 'said', 'they'): 1,
#          ('said', 'they', 'realize'): 1,
#          ('they', 'realize', '``'): 1,
#          ('realize', '``', 'a'): 1,
#          ('``', 'a', 'proportionate'): 1,
#          ('a', 'proportionate', 'distribution'): 1,
#          ('proportionate', 'distribution', 'of'): 1,
#          ('distribution', 'of', 'these'): 1,
#          ('of', 'these', 'funds'): 1,
#          ('these', 'funds', 'might'): 1,
#          ('funds', 'might', 'UNK'): 1,
#          ('might', 'UNK', 'this'): 1,
#          ('UNK', 'this', 'program'): 1,
#          ('this', 'program', 'in'): 1,
#          ('program', 'in', 'our'): 1,
#          ('in', 'our', 'less'): 1,
#          ('our', 'less', 'populous'): 1,
#          ('less', 'populous', 'counties'): 1,
#          ('populous', 'counties', "''"): 1,
#          ('counties', "''", '.'): 1,
#          ('START', 'START', 'nevertheless'): 1,
#          ('START', 'nevertheless', ','): 1,
#          ('nevertheless', ',', '``'): 1,
#          (',', '``', 'we'): 4,
#          ('``', 'we', 'feel'): 1,
#          ('we', 'feel', 'that'): 1,
#          ('feel', 'that', 'in'): 1,
#          ('that', 'in', 'the'): 2,
#          ('in', 'the', 'future'): 3,
#          ('the', 'future', 'fulton'): 1,
#          ('future', 'fulton', 'county'): 1,
#          ('fulton', 'county', 'should'): 1,
#          ('county', 'should', 'receive'): 1,
#          ('should', 'receive', 'some'): 1,
#          ('receive', 'some', 'portion'): 1,
#          ('some', 'portion', 'of'): 1,
#          ('portion', 'of', 'these'): 1,
#          ('of', 'these', 'available'): 1,
#          ('these', 'available', 'funds'): 1,
#          ('available', 'funds', "''"): 1,
#          ('funds', "''", ','): 2,
#          (',', 'the', 'jurors'): 1,
#          ('jurors', 'said', '.'): 1,
#          ('said', '.', 'STOP'): 36,
#          ('START', '``', 'failure'): 1,
#          ('``', 'failure', 'to'): 1,
#          ('failure', 'to', 'do'): 1,
#          ('to', 'do', 'this'): 1,
#          ('do', 'this', 'will'): 1,
#          ('this', 'will', 'continue'): 1,
#          ('will', 'continue', 'to'): 1,
#          ('continue', 'to', 'place'): 1,
#          ('to', 'place', 'a'): 1,
#          ('place', 'a', 'disproportionate'): 1,
#          ('a', 'disproportionate', 'burden'): 1,
#          ('disproportionate', 'burden', "''"): 1,
#          ('burden', "''", 'on'): 1,
#          ("''", 'on', 'fulton'): 1,
#          ('on', 'fulton', 'taxpayers'): 1,
#          ('fulton', 'taxpayers', '.'): 1,
#          ('taxpayers', '.', 'STOP'): 1,
#          ('the', 'jury', 'also'): 1,
#          ('jury', 'also', 'commented'): 1,
#          ('also', 'commented', 'on'): 1,
#          ('commented', 'on', 'the'): 1,
#          ('on', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'ordinary'): 1,
#          ('fulton', 'ordinary', "'s"): 1,
#          ('ordinary', "'s", 'court'): 1,
#          ("'s", 'court', 'which'): 1,
#          ('court', 'which', 'has'): 1,
#          ('which', 'has', 'been'): 2,
#          ('has', 'been', 'under'): 1,
#          ('been', 'under', 'fire'): 1,
#          ('under', 'fire', 'for'): 1,
#          ('fire', 'for', 'its'): 1,
#          ('for', 'its', 'practices'): 1,
#          ('its', 'practices', 'in'): 1,
#          ('practices', 'in', 'the'): 1,
#          ('in', 'the', 'appointment'): 1,
#          ('the', 'appointment', 'of'): 3,
#          ('appointment', 'of', 'UNK'): 1,
#          ('of', 'UNK', ','): 6,
#          ('UNK', ',', 'guardians'): 1,
#          (',', 'guardians', 'and'): 1,
#          ('guardians', 'and', 'administrators'): 1,
#          ('and', 'administrators', 'and'): 1,
#          ('administrators', 'and', 'the'): 1,
#          ('and', 'the', 'awarding'): 1,
#          ('the', 'awarding', 'of'): 1,
#          ('awarding', 'of', 'fees'): 1,
#          ('of', 'fees', 'and'): 1,
#          ('fees', 'and', 'compensation'): 1,
#          ('and', 'compensation', '.'): 1,
#          ('compensation', '.', 'STOP'): 1,
#          ('said', 'it', 'found'): 1,
#          ('it', 'found', 'the'): 1,
#          ('found', 'the', 'court'): 1,
#          ('the', 'court', '``'): 1,
#          ('court', '``', 'has'): 1,
#          ('``', 'has', 'incorporated'): 1,
#          ('has', 'incorporated', 'into'): 1,
#          ('incorporated', 'into', 'its'): 1,
#          ('into', 'its', 'operating'): 1,
#          ('its', 'operating', 'procedures'): 1,
#          ('operating', 'procedures', 'the'): 1,
#          ('procedures', 'the', 'recommendations'): 1,
#          ('the', 'recommendations', "''"): 1,
#          ('recommendations', "''", 'of'): 1,
#          ("''", 'of', 'two'): 1,
#          ('of', 'two', 'previous'): 1,
#          ('two', 'previous', 'grand'): 1,
#          ('previous', 'grand', 'UNK'): 1,
#          ('grand', 'UNK', ','): 1,
#          ('UNK', ',', 'the'): 4,
#          (',', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'bar'): 1,
#          ('atlanta', 'bar', 'association'): 1,
#          ('bar', 'association', 'and'): 1,
#          ('association', 'and', 'an'): 1,
#          ('and', 'an', 'interim'): 1,
#          ('an', 'interim', 'citizens'): 1,
#          ('interim', 'citizens', 'committee'): 1,
#          ('citizens', 'committee', '.'): 1,
#          ('committee', '.', 'STOP'): 10,
#          ('START', '``', 'these'): 1,
#          ('``', 'these', 'actions'): 1,
#          ('these', 'actions', 'should'): 1,
#          ('actions', 'should', 'serve'): 1,
#          ('should', 'serve', 'to'): 1,
#          ('serve', 'to', 'protect'): 1,
#          ('to', 'protect', 'in'): 1,
#          ('protect', 'in', 'fact'): 1,
#          ('in', 'fact', 'and'): 1,
#          ('fact', 'and', 'in'): 1,
#          ('and', 'in', 'effect'): 1,
#          ('in', 'effect', 'the'): 1,
#          ('effect', 'the', 'court'): 1,
#          ('the', 'court', "'s"): 1,
#          ('court', "'s", 'wards'): 1,
#          ("'s", 'wards', 'from'): 1,
#          ('wards', 'from', 'undue'): 1,
#          ('from', 'undue', 'costs'): 1,
#          ('undue', 'costs', 'and'): 1,
#          ('costs', 'and', 'its'): 1,
#          ('and', 'its', 'appointed'): 1,
#          ('its', 'appointed', 'and'): 1,
#          ('appointed', 'and', 'elected'): 1,
#          ('and', 'elected', 'servants'): 1,
#          ('elected', 'servants', 'from'): 1,
#          ('servants', 'from', 'UNK'): 1,
#          ('from', 'UNK', 'criticisms'): 1,
#          ('UNK', 'criticisms', "''"): 1,
#          ('criticisms', "''", ','): 1,
#          ('jury', 'said', '.'): 1,
#          ('START', 'START', 'regarding'): 1,
#          ('START', 'regarding', 'atlanta'): 1,
#          ('regarding', 'atlanta', "'s"): 1,
#          ('atlanta', "'s", 'new'): 1,
#          ("'s", 'new', 'multi-million-dollar'): 1,
#          ('new', 'multi-million-dollar', 'airport'): 1,
#          ('multi-million-dollar', 'airport', ','): 1,
#          ('airport', ',', 'the'): 1,
#          ('the', 'jury', 'recommended'): 2,
#          ('jury', 'recommended', '``'): 1,
#          ('recommended', '``', 'that'): 1,
#          ('``', 'that', 'when'): 1,
#          ('that', 'when', 'the'): 1,
#          ('when', 'the', 'new'): 1,
#          ('the', 'new', 'management'): 1,
#          ('new', 'management', 'takes'): 1,
#          ('management', 'takes', 'charge'): 1,
#          ('takes', 'charge', 'jan'): 1,
#          ('charge', 'jan', '&'): 1,
#          ('jan', '&', '1'): 3,
#          ('&', '1', 'the'): 1,
#          ('1', 'the', 'airport'): 1,
#          ('the', 'airport', 'be'): 1,
#          ('airport', 'be', 'operated'): 1,
#          ('be', 'operated', 'in'): 1,
#          ('operated', 'in', 'a'): 1,
#          ('in', 'a', 'manner'): 1,
#          ('a', 'manner', 'that'): 1,
#          ('manner', 'that', 'will'): 1,
#          ('that', 'will', 'eliminate'): 1,
#          ('will', 'eliminate', 'political'): 1,
#          ('eliminate', 'political', 'influences'): 1,
#          ('political', 'influences', "''"): 1,
#          ('influences', "''", '.'): 1,
#          ('the', 'jury', 'did'): 1,
#          ('jury', 'did', 'not'): 1,
#          ('did', 'not', 'elaborate'): 1,
#          ('not', 'elaborate', ','): 1,
#          ('elaborate', ',', 'but'): 1,
#          (',', 'but', 'it'): 1,
#          ('but', 'it', 'added'): 1,
#          ('it', 'added', 'that'): 1,
#          ('added', 'that', '``'): 1,
#          ('that', '``', 'there'): 1,
#          ('``', 'there', 'should'): 1,
#          ('there', 'should', 'be'): 2,
#          ('should', 'be', 'periodic'): 1,
#          ('be', 'periodic', 'surveillance'): 1,
#          ('periodic', 'surveillance', 'of'): 1,
#          ('surveillance', 'of', 'the'): 1,
#          ('of', 'the', 'pricing'): 1,
#          ('the', 'pricing', 'practices'): 1,
#          ('pricing', 'practices', 'of'): 1,
#          ('practices', 'of', 'the'): 1,
#          ('of', 'the', 'concessionaires'): 1,
#          ('the', 'concessionaires', 'for'): 1,
#          ('concessionaires', 'for', 'the'): 1,
#          ('for', 'the', 'purpose'): 1,
#          ('the', 'purpose', 'of'): 1,
#          ('purpose', 'of', 'keeping'): 1,
#          ('of', 'keeping', 'the'): 1,
#          ('keeping', 'the', 'prices'): 1,
#          ('the', 'prices', 'reasonable'): 1,
#          ('prices', 'reasonable', "''"): 1,
#          ('reasonable', "''", '.'): 1,
#          ('START', 'START', 'on'): 4,
#          ('START', 'on', 'other'): 1,
#          ('on', 'other', 'matters'): 1,
#          ('other', 'matters', ','): 1,
#          ('matters', ',', 'the'): 1,
#          ('jury', 'recommended', 'that'): 1,
#          ('recommended', 'that', ':'): 1,
#          ('that', ':', '_'): 1,
#          (':', '_', '-lrb-'): 1,
#          ('_', '-lrb-', '1'): 1,
#          ('-lrb-', '1', '-rrb-'): 1,
#          ('1', '-rrb-', '_'): 1,
#          ('-rrb-', '_', 'four'): 1,
#          ('_', 'four', 'additional'): 1,
#          ('four', 'additional', 'deputies'): 1,
#          ('additional', 'deputies', 'be'): 1,
#          ('deputies', 'be', 'employed'): 1,
#          ('be', 'employed', 'at'): 1,
#          ('employed', 'at', 'the'): 1,
#          ('at', 'the', 'fulton'): 1,
#          ('fulton', 'county', 'jail'): 1,
#          ('county', 'jail', 'and'): 1,
#          ('jail', 'and', '``'): 1,
#          ('and', '``', 'a'): 1,
#          ('``', 'a', 'doctor'): 1,
#          ('a', 'doctor', ','): 1,
#          ('doctor', ',', 'medical'): 1,
#          (',', 'medical', 'UNK'): 1,
#          ('medical', 'UNK', 'or'): 1,
#          ('UNK', 'or', 'UNK'): 1,
#          ('or', 'UNK', 'be'): 1,
#          ('UNK', 'be', 'employed'): 1,
#          ('be', 'employed', 'for'): 1,
#          ('employed', 'for', 'night'): 1,
#          ('for', 'night', 'and'): 1,
#          ('night', 'and', 'weekend'): 1,
#          ('and', 'weekend', 'duty'): 1,
#          ('weekend', 'duty', 'at'): 1,
#          ('duty', 'at', 'the'): 1,
#          ('at', 'the', 'jail'): 1,
#          ('the', 'jail', "''"): 1,
#          ('jail', "''", '.'): 1,
#          ('START', 'START', '_'): 47,
#          ('START', '_', '-lrb-'): 1,
#          ('_', '-lrb-', '2'): 1,
#          ('-lrb-', '2', '-rrb-'): 1,
#          ('2', '-rrb-', '_'): 1,
#          ('-rrb-', '_', 'fulton'): 1,
#          ('_', 'fulton', 'legislators'): 1,
#          ('fulton', 'legislators', '``'): 1,
#          ('legislators', '``', 'work'): 1,
#          ('``', 'work', 'with'): 1,
#          ('work', 'with', 'city'): 1,
#          ('with', 'city', 'officials'): 1,
#          ('city', 'officials', 'to'): 1,
#          ('officials', 'to', 'pass'): 1,
#          ('to', 'pass', 'enabling'): 1,
#          ('pass', 'enabling', 'legislation'): 1,
#          ('enabling', 'legislation', 'that'): 1,
#          ('legislation', 'that', 'will'): 1,
#          ('that', 'will', 'permit'): 1,
#          ('will', 'permit', 'the'): 1,
#          ('permit', 'the', 'establishment'): 1,
#          ('the', 'establishment', 'of'): 1,
#          ('establishment', 'of', 'a'): 2,
#          ('of', 'a', 'fair'): 1,
#          ('a', 'fair', 'and'): 1,
#          ('fair', 'and', 'equitable'): 1,
#          ('and', 'equitable', "''"): 1,
#          ('equitable', "''", 'pension'): 1,
#          ("''", 'pension', 'plan'): 1,
#          ('pension', 'plan', 'for'): 1,
#          ('plan', 'for', 'city'): 1,
#          ('for', 'city', 'employes'): 1,
#          ('city', 'employes', '.'): 1,
#          ('employes', '.', 'STOP'): 1,
#          ('the', 'jury', 'praised'): 1,
#          ('jury', 'praised', 'the'): 1,
#          ('praised', 'the', 'administration'): 1,
#          ('the', 'administration', 'and'): 1,
#          ('administration', 'and', 'operation'): 1,
#          ('and', 'operation', 'of'): 2,
#          ('operation', 'of', 'the'): 2,
#          ('of', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'police'): 1,
#          ('atlanta', 'police', 'department'): 1,
#          ('police', 'department', ','): 1,
#          (',', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'tax'): 1,
#          ('fulton', 'tax', 'commissioner'): 1,
#          ('tax', 'commissioner', "'s"): 1,
#          ('commissioner', "'s", 'office'): 1,
#          ("'s", 'office', ','): 1,
#          ('office', ',', 'the'): 1,
#          (',', 'the', 'UNK'): 4,
#          ('the', 'UNK', 'and'): 2,
#          ('UNK', 'and', 'UNK'): 1,
#          ('and', 'UNK', 'prison'): 1,
#          ('UNK', 'prison', 'farms'): 1,
#          ('prison', 'farms', ','): 1,
#          ('farms', ',', 'grady'): 1,
#          (',', 'grady', 'hospital'): 1,
#          ('grady', 'hospital', 'and'): 1,
#          ('hospital', 'and', 'the'): 1,
#          ('and', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'health'): 1,
#          ('fulton', 'health', 'department'): 1,
#          ('health', 'department', '.'): 1,
#          ('department', '.', 'STOP'): 2,
#          ('START', 'START', 'mayor'): 1,
#          ('START', 'mayor', 'william'): 1,
#          ('mayor', 'william', 'b'): 1,
#          ('william', 'b', '&'): 1,
#          ('b', '&', 'hartsfield'): 1,
#          ('&', 'hartsfield', 'filed'): 1,
#          ('hartsfield', 'filed', 'suit'): 1,
#          ('filed', 'suit', 'for'): 1,
#          ('suit', 'for', 'divorce'): 1,
#          ('for', 'divorce', 'from'): 1,
#          ('divorce', 'from', 'his'): 1,
#          ('from', 'his', 'wife'): 1,
#          ('his', 'wife', ','): 1,
#          ('wife', ',', 'pearl'): 1,
#          (',', 'pearl', 'williams'): 1,
#          ('pearl', 'williams', 'hartsfield'): 1,
#          ('williams', 'hartsfield', ','): 1,
#          ('hartsfield', ',', 'in'): 1,
#          (',', 'in', 'fulton'): 1,
#          ('in', 'fulton', 'superior'): 1,
#          ('superior', 'court', 'friday'): 1,
#          ('court', 'friday', '.'): 1,
#          ('friday', '.', 'STOP'): 2,
#          ('START', 'START', 'his'): 11,
#          ('START', 'his', 'petition'): 1,
#          ('his', 'petition', 'charged'): 1,
#          ('petition', 'charged', 'mental'): 1,
#          ('charged', 'mental', 'cruelty'): 1,
#          ('mental', 'cruelty', '.'): 1,
#          ('cruelty', '.', 'STOP'): 1,
#          ('START', 'the', 'couple'): 1,
#          ('the', 'couple', 'was'): 1,
#          ('couple', 'was', 'married'): 1,
#          ('was', 'married', 'aug'): 1,
#          ('married', 'aug', '&'): 1,
#          ('aug', '&', '2'): 1,
#          ('&', '2', ','): 1,
#          ('2', ',', '1913'): 1,
#          (',', '1913', '.'): 1,
#          ('1913', '.', 'STOP'): 1,
#          ('START', 'START', 'they'): 11,
#          ('START', 'they', 'have'): 1,
#          ('they', 'have', 'a'): 1,
#          ('have', 'a', 'son'): 1,
#          ('a', 'son', ','): 1,
#          ('son', ',', 'william'): 1,
#          (',', 'william', 'berry'): 1,
#          ('william', 'berry', 'jr'): 1,
#          ('berry', 'jr', '&'): 1,
#          ('jr', '&', ','): 4,
#          ('&', ',', 'and'): 2,
#          (',', 'and', 'a'): 3,
#          ('and', 'a', 'daughter'): 1,
#          ('a', 'daughter', ','): 2,
#          ('daughter', ',', 'mrs'): 1,
#          (',', 'mrs', '&'): 1,
#          ('mrs', '&', 'j'): 1,
#          ('&', 'j', '&'): 4,
#          ('j', '&', 'm'): 1,
#          ('&', 'm', '&'): 7,
#          ('m', '&', 'UNK'): 3,
#          ('&', 'UNK', 'of'): 2,
#          ('UNK', 'of', 'griffin'): 1,
#          ('of', 'griffin', '.'): 1,
#          ('griffin', '.', 'STOP'): 2,
#          ('START', 'START', 'attorneys'): 1,
#          ('START', 'attorneys', 'for'): 1,
#          ('attorneys', 'for', 'the'): 1,
#          ('for', 'the', 'mayor'): 1,
#          ('the', 'mayor', 'said'): 2,
#          ('mayor', 'said', 'that'): 1,
#          ('said', 'that', 'an'): 1,
#          ('that', 'an', 'UNK'): 1,
#          ('an', 'UNK', 'property'): 1,
#          ('UNK', 'property', 'settlement'): 1,
#          ('property', 'settlement', 'has'): 1,
#          ('settlement', 'has', 'been'): 1,
#          ('has', 'been', 'agreed'): 1,
#          ('been', 'agreed', 'upon'): 1,
#          ('agreed', 'upon', '.'): 1,
#          ('upon', '.', 'STOP'): 1,
#          ('START', 'the', 'petition'): 2,
#          ('the', 'petition', 'listed'): 1,
#          ('petition', 'listed', 'the'): 1,
#          ('listed', 'the', 'mayor'): 1,
#          ('the', 'mayor', "'s"): 5,
#          ('mayor', "'s", 'occupation'): 1,
#          ("'s", 'occupation', 'as'): 1,
#          ('occupation', 'as', '``'): 1,
#          ('as', '``', 'attorney'): 1,
#          ('``', 'attorney', "''"): 1,
#          ('attorney', "''", 'and'): 1,
#          ("''", 'and', 'his'): 1,
#          ('and', 'his', 'age'): 1,
#          ('his', 'age', 'as'): 1,
#          ('age', 'as', '71'): 1,
#          ('as', '71', '.'): 1,
#          ('71', '.', 'STOP'): 1,
#          ('START', 'it', 'listed'): 1,
#          ('it', 'listed', 'his'): 1,
#          ('listed', 'his', 'wife'): 1,
#          ('his', 'wife', "'s"): 1,
#          ('wife', "'s", 'age'): 1,
#          ("'s", 'age', 'as'): 1,
#          ('age', 'as', '74'): 1,
#          ('as', '74', 'and'): 1,
#          ('74', 'and', 'place'): 1,
#          ('and', 'place', 'of'): 1,
#          ('place', 'of', 'birth'): 1,
#          ('of', 'birth', 'as'): 1,
#          ('birth', 'as', 'opelika'): 1,
#          ('as', 'opelika', ','): 1,
#          ('opelika', ',', 'ala'): 1,
#          (',', 'ala', '&'): 1,
#          ('ala', '&', '.'): 1,
#          ('the', 'petition', 'said'): 1,
#          ('petition', 'said', 'that'): 1,
#          ('said', 'that', 'the'): 5,
#          ('that', 'the', 'couple'): 1,
#          ('the', 'couple', 'has'): 1,
#          ('couple', 'has', 'not'): 1,
#          ('has', 'not', 'lived'): 1,
#          ('not', 'lived', 'together'): 1,
#          ('lived', 'together', 'as'): 1,
#          ('together', 'as', 'man'): 1,
#          ('as', 'man', 'and'): 1,
#          ('man', 'and', 'wife'): 1,
#          ('and', 'wife', 'for'): 1,
#          ('wife', 'for', 'more'): 1,
#          ('for', 'more', 'than'): 2,
#          ('more', 'than', 'a'): 3,
#          ('than', 'a', 'year'): 2,
#          ('a', 'year', '.'): 3,
#          ('year', '.', 'STOP'): 12,
#          ('START', 'the', 'hartsfield'): 1,
#          ('the', 'hartsfield', 'home'): 1,
#          ('hartsfield', 'home', 'is'): 1,
#          ('home', 'is', 'at'): 1,
#          ('is', 'at', 'UNK'): 1,
#          ('at', 'UNK', 'e'): 1,
#          ('UNK', 'e', '&'): 1,
#          ('e', '&', 'pelham'): 1,
#          ('&', 'pelham', 'rd'): 1,
#          ('pelham', 'rd', '&'): 1,
#          ('rd', '&', 'ne'): 1,
#          ('&', 'ne', '.'): 1,
#          ('ne', '.', 'STOP'): 1,
#          ('START', 'START', 'henry'): 1,
#          ('START', 'henry', 'l'): 1,
#          ('henry', 'l', '&'): 1,
#          ('l', '&', 'bowden'): 1,
#          ('&', 'bowden', 'was'): 1,
#          ('bowden', 'was', 'listed'): 1,
#          ('was', 'listed', 'on'): 1,
#          ('listed', 'on', 'the'): 2,
#          ('on', 'the', 'petition'): 1,
#          ('the', 'petition', 'as'): 1,
#          ('petition', 'as', 'the'): 1,
#          ('as', 'the', 'mayor'): 1,
#          ('mayor', "'s", 'attorney'): 1,
#          ("'s", 'attorney', '.'): 1,
#          ('attorney', '.', 'STOP'): 2,
#          ('START', 'START', 'hartsfield'): 1,
#          ('START', 'hartsfield', 'has'): 1,
#          ('hartsfield', 'has', 'been'): 1,
#          ('has', 'been', 'mayor'): 1,
#          ('been', 'mayor', 'of'): 1,
#          ('mayor', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', ','): 1,
#          ('atlanta', ',', 'with'): 1,
#          (',', 'with', 'exception'): 1,
#          ('with', 'exception', 'of'): 1,
#          ('exception', 'of', 'one'): 1,
#          ('of', 'one', 'brief'): 1,
#          ('one', 'brief', 'interlude'): 1,
#          ('brief', 'interlude', ','): 1,
#          ('interlude', ',', 'since'): 1,
#          (',', 'since', '1937'): 1,
#          ('since', '1937', '.'): 1,
#          ('1937', '.', 'STOP'): 1,
#          ('START', 'his', 'political'): 1,
#          ('his', 'political', 'career'): 1,
#          ('political', 'career', 'goes'): 1,
#          ('career', 'goes', 'back'): 1,
#          ('goes', 'back', 'to'): 1,
#          ('back', 'to', 'his'): 1,
#          ('to', 'his', 'election'): 1,
#          ('his', 'election', 'to'): 1,
#          ('election', 'to', 'city'): 1,
#          ('to', 'city', 'council'): 1,
#          ('city', 'council', 'in'): 1,
#          ('council', 'in', '1923'): 1,
#          ('in', '1923', '.'): 1,
#          ('1923', '.', 'STOP'): 1,
#          ('START', 'the', 'mayor'): 4,
#          ('mayor', "'s", 'present'): 1,
#          ("'s", 'present', 'term'): 1,
#          ('present', 'term', 'of'): 1,
#          ('term', 'of', 'office'): 1,
#          ('of', 'office', 'UNK'): 1,
#          ('office', 'UNK', 'jan'): 1,
#          ('UNK', 'jan', '&'): 1,
#          ('&', '1', '.'): 1,
#          ('1', '.', 'STOP'): 4,
#          ('START', 'START', 'he'): 63,
#          ('START', 'he', 'will'): 5,
#          ('he', 'will', 'be'): 2,
#          ('will', 'be', 'succeeded'): 2,
#          ('be', 'succeeded', 'by'): 2,
#          ('succeeded', 'by', 'ivan'): 1,
#          ('by', 'ivan', 'allen'): 1,
#          ('&', ',', 'who'): 1,
#          (',', 'who', 'became'): 1,
#          ('who', 'became', 'a'): 1,
#          ('became', 'a', 'candidate'): 1,
#          ('a', 'candidate', 'in'): 3,
#          ('candidate', 'in', 'the'): 2,
#          ('in', 'the', 'sept'): 2,
#          ('the', 'sept', '&'): 2,
#          ('sept', '&', '13'): 1,
#          ('&', '13', 'primary'): 1,
#          ('13', 'primary', 'after'): 1,
#          ('primary', 'after', 'mayor'): 1,
#          ('after', 'mayor', 'hartsfield'): 1,
#          ('mayor', 'hartsfield', 'announced'): 1,
#          ('hartsfield', 'announced', 'that'): 1,
#          ('announced', 'that', 'he'): 1,
#          ('that', 'he', 'would'): 3,
#          ('he', 'would', 'not'): 2,
#          ('would', 'not', 'run'): 1,
#          ('not', 'run', 'for'): 1,
#          ('run', 'for', 'reelection'): 1,
#          ('for', 'reelection', '.'): 1,
#          ('reelection', '.', 'STOP'): 1,
#          ('START', 'START', 'georgia'): 1,
#          ('START', 'georgia', 'republicans'): 1,
#          ('georgia', 'republicans', 'are'): 1,
#          ('republicans', 'are', 'getting'): 1,
#          ('are', 'getting', 'strong'): 1,
#          ('getting', 'strong', 'encouragement'): 1,
#          ('strong', 'encouragement', 'to'): 1,
#          ('encouragement', 'to', 'enter'): 1,
#          ('to', 'enter', 'a'): 2,
#          ('enter', 'a', 'candidate'): 2,
#          ('in', 'the', '1962'): 1,
#          ('the', '1962', 'governor'): 1,
#          ('1962', 'governor', "'s"): 1,
#          ('governor', "'s", 'race'): 1,
#          ("'s", 'race', ','): 1,
#          ('race', ',', 'a'): 1,
#          (',', 'a', 'top'): 1,
#          ('a', 'top', 'official'): 1,
#          ('top', 'official', 'said'): 1,
#          ('official', 'said', 'wednesday'): 1,
#          ('said', 'wednesday', '.'): 1,
#          ('wednesday', '.', 'STOP'): 2,
#          ('START', 'START', 'robert'): 1,
#          ('START', 'robert', 'snodgrass'): 1,
#          ('robert', 'snodgrass', ','): 1,
#          ('snodgrass', ',', 'state'): 1,
#          (',', 'state', 'gop'): 1,
#          ('state', 'gop', 'chairman'): 1,
#          ('gop', 'chairman', ','): 1,
#          ('chairman', ',', 'said'): 1,
#          (',', 'said', 'a'): 2,
#          ('said', 'a', 'meeting'): 1,
#          ('a', 'meeting', 'held'): 1,
#          ('meeting', 'held', 'tuesday'): 1,
#          ...})

# %%
model.smoothed_trigram_probability(('START', 'START', 'the'))
# Out:
# TRIGRAM IS:  ('START', 'START', 'the')
# 0.019999999999999997

# %%
model.raw_trigram_probability(('the', 'fulton', 'county'))
# Out:
# trigram got is ('the', 'fulton', 'county')
# 0.5

# %%
model.bigramcounts[('the','fulton')]
# Out:
# 6

# %%
model.trigramcounts[('the', 'fulton', 'county')]
# Out:
# 3

# %%
model.trigramcounts
# Out:
# Counter({('START', 'START', 'the'): 196,
#          ('START', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'county'): 3,
#          ('fulton', 'county', 'grand'): 1,
#          ('county', 'grand', 'jury'): 1,
#          ('grand', 'jury', 'said'): 1,
#          ('jury', 'said', 'friday'): 1,
#          ('said', 'friday', 'an'): 1,
#          ('friday', 'an', 'investigation'): 1,
#          ('an', 'investigation', 'of'): 1,
#          ('investigation', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', "'s"): 1,
#          ('atlanta', "'s", 'recent'): 1,
#          ("'s", 'recent', 'primary'): 1,
#          ('recent', 'primary', 'election'): 1,
#          ('primary', 'election', 'produced'): 1,
#          ('election', 'produced', '``'): 1,
#          ('produced', '``', 'no'): 1,
#          ('``', 'no', 'evidence'): 1,
#          ('no', 'evidence', "''"): 1,
#          ('evidence', "''", 'that'): 1,
#          ("''", 'that', 'any'): 1,
#          ('that', 'any', 'irregularities'): 1,
#          ('any', 'irregularities', 'took'): 1,
#          ('irregularities', 'took', 'place'): 1,
#          ('took', 'place', '.'): 1,
#          ('place', '.', 'STOP'): 1,
#          ('START', 'the', 'jury'): 6,
#          ('the', 'jury', 'further'): 1,
#          ('jury', 'further', 'said'): 1,
#          ('further', 'said', 'in'): 1,
#          ('said', 'in', 'UNK'): 1,
#          ('in', 'UNK', 'UNK'): 1,
#          ('UNK', 'UNK', 'that'): 1,
#          ('UNK', 'that', 'the'): 1,
#          ('that', 'the', 'city'): 5,
#          ('the', 'city', 'executive'): 1,
#          ('city', 'executive', 'committee'): 1,
#          ('executive', 'committee', ','): 1,
#          ('committee', ',', 'which'): 1,
#          (',', 'which', 'had'): 2,
#          ('which', 'had', 'over-all'): 1,
#          ('had', 'over-all', 'charge'): 1,
#          ('over-all', 'charge', 'of'): 1,
#          ('charge', 'of', 'the'): 1,
#          ('of', 'the', 'election'): 1,
#          ('the', 'election', ','): 2,
#          ('election', ',', '``'): 1,
#          (',', '``', 'deserves'): 1,
#          ('``', 'deserves', 'the'): 1,
#          ('deserves', 'the', 'praise'): 1,
#          ('the', 'praise', 'and'): 1,
#          ('praise', 'and', 'thanks'): 1,
#          ('and', 'thanks', 'of'): 1,
#          ('thanks', 'of', 'the'): 1,
#          ('of', 'the', 'city'): 5,
#          ('the', 'city', 'of'): 1,
#          ('city', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', "''"): 1,
#          ('atlanta', "''", 'for'): 1,
#          ("''", 'for', 'the'): 1,
#          ('for', 'the', 'manner'): 1,
#          ('the', 'manner', 'in'): 1,
#          ('manner', 'in', 'which'): 2,
#          ('in', 'which', 'the'): 3,
#          ('which', 'the', 'election'): 1,
#          ('the', 'election', 'was'): 2,
#          ('election', 'was', 'conducted'): 1,
#          ('was', 'conducted', '.'): 1,
#          ('conducted', '.', 'STOP'): 1,
#          ('START', 'the', 'UNK'): 3,
#          ('the', 'UNK', 'term'): 1,
#          ('UNK', 'term', 'jury'): 1,
#          ('term', 'jury', 'had'): 1,
#          ('jury', 'had', 'been'): 1,
#          ('had', 'been', 'charged'): 1,
#          ('been', 'charged', 'by'): 1,
#          ('charged', 'by', 'fulton'): 1,
#          ('by', 'fulton', 'superior'): 1,
#          ('fulton', 'superior', 'court'): 2,
#          ('superior', 'court', 'judge'): 2,
#          ('court', 'judge', 'UNK'): 1,
#          ('judge', 'UNK', 'UNK'): 1,
#          ('UNK', 'UNK', 'to'): 2,
#          ('UNK', 'to', 'investigate'): 1,
#          ('to', 'investigate', 'reports'): 1,
#          ('investigate', 'reports', 'of'): 1,
#          ('reports', 'of', 'possible'): 1,
#          ('of', 'possible', '``'): 1,
#          ('possible', '``', 'irregularities'): 1,
#          ('``', 'irregularities', "''"): 1,
#          ('irregularities', "''", 'in'): 1,
#          ("''", 'in', 'the'): 1,
#          ('in', 'the', 'hard-fought'): 1,
#          ('the', 'hard-fought', 'primary'): 1,
#          ('hard-fought', 'primary', 'which'): 1,
#          ('primary', 'which', 'was'): 1,
#          ('which', 'was', 'won'): 1,
#          ('was', 'won', 'by'): 1,
#          ('won', 'by', 'UNK'): 1,
#          ('by', 'UNK', 'ivan'): 1,
#          ('UNK', 'ivan', 'allen'): 1,
#          ('ivan', 'allen', 'jr'): 2,
#          ('allen', 'jr', '&'): 2,
#          ('jr', '&', '.'): 2,
#          ('&', '.', 'STOP'): 16,
#          ('START', 'START', '``'): 73,
#          ('START', '``', 'only'): 1,
#          ('``', 'only', 'a'): 1,
#          ('only', 'a', 'relative'): 1,
#          ('a', 'relative', 'handful'): 1,
#          ('relative', 'handful', 'of'): 1,
#          ('handful', 'of', 'such'): 1,
#          ('of', 'such', 'reports'): 1,
#          ('such', 'reports', 'was'): 1,
#          ('reports', 'was', 'received'): 1,
#          ('was', 'received', "''"): 1,
#          ('received', "''", ','): 1,
#          ("''", ',', 'the'): 12,
#          (',', 'the', 'jury'): 7,
#          ('the', 'jury', 'said'): 7,
#          ('jury', 'said', ','): 3,
#          ('said', ',', '``'): 14,
#          (',', '``', 'considering'): 1,
#          ('``', 'considering', 'the'): 1,
#          ('considering', 'the', 'widespread'): 1,
#          ('the', 'widespread', 'interest'): 1,
#          ('widespread', 'interest', 'in'): 1,
#          ('interest', 'in', 'the'): 1,
#          ('in', 'the', 'election'): 2,
#          ('election', ',', 'the'): 1,
#          (',', 'the', 'number'): 1,
#          ('the', 'number', 'of'): 3,
#          ('number', 'of', 'voters'): 1,
#          ('of', 'voters', 'and'): 1,
#          ('voters', 'and', 'the'): 1,
#          ('and', 'the', 'size'): 1,
#          ('the', 'size', 'of'): 1,
#          ('size', 'of', 'this'): 1,
#          ('of', 'this', 'city'): 1,
#          ('this', 'city', "''"): 1,
#          ('city', "''", '.'): 1,
#          ("''", '.', 'STOP'): 95,
#          ('jury', 'said', 'it'): 3,
#          ('said', 'it', 'did'): 1,
#          ('it', 'did', 'find'): 1,
#          ('did', 'find', 'that'): 1,
#          ('find', 'that', 'many'): 1,
#          ('that', 'many', 'of'): 1,
#          ('many', 'of', 'georgia'): 1,
#          ('of', 'georgia', "'s"): 4,
#          ('georgia', "'s", 'registration'): 1,
#          ("'s", 'registration', 'and'): 1,
#          ('registration', 'and', 'election'): 1,
#          ('and', 'election', 'laws'): 1,
#          ('election', 'laws', '``'): 1,
#          ('laws', '``', 'are'): 1,
#          ('``', 'are', 'outmoded'): 1,
#          ('are', 'outmoded', 'or'): 1,
#          ('outmoded', 'or', 'inadequate'): 1,
#          ('or', 'inadequate', 'and'): 1,
#          ('inadequate', 'and', 'often'): 1,
#          ('and', 'often', 'ambiguous'): 1,
#          ('often', 'ambiguous', "''"): 1,
#          ('ambiguous', "''", '.'): 1,
#          ('START', 'START', 'it'): 32,
#          ('START', 'it', 'recommended'): 1,
#          ('it', 'recommended', 'that'): 1,
#          ('recommended', 'that', 'fulton'): 1,
#          ('that', 'fulton', 'legislators'): 1,
#          ('fulton', 'legislators', 'act'): 1,
#          ('legislators', 'act', '``'): 1,
#          ('act', '``', 'to'): 1,
#          ('``', 'to', 'have'): 1,
#          ('to', 'have', 'these'): 1,
#          ('have', 'these', 'laws'): 1,
#          ('these', 'laws', 'studied'): 1,
#          ('laws', 'studied', 'and'): 1,
#          ('studied', 'and', 'revised'): 1,
#          ('and', 'revised', 'to'): 1,
#          ('revised', 'to', 'the'): 1,
#          ('to', 'the', 'end'): 1,
#          ('the', 'end', 'of'): 2,
#          ('end', 'of', 'modernizing'): 1,
#          ('of', 'modernizing', 'and'): 1,
#          ('modernizing', 'and', 'improving'): 1,
#          ('and', 'improving', 'them'): 1,
#          ('improving', 'them', "''"): 1,
#          ('them', "''", '.'): 3,
#          ('START', 'the', 'grand'): 2,
#          ('the', 'grand', 'jury'): 4,
#          ('grand', 'jury', 'commented'): 1,
#          ('jury', 'commented', 'on'): 1,
#          ('commented', 'on', 'a'): 1,
#          ('on', 'a', 'number'): 1,
#          ('a', 'number', 'of'): 5,
#          ('number', 'of', 'other'): 1,
#          ('of', 'other', 'topics'): 1,
#          ('other', 'topics', ','): 1,
#          ('topics', ',', 'among'): 1,
#          (',', 'among', 'them'): 1,
#          ('among', 'them', 'the'): 1,
#          ('them', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'and'): 1,
#          ('atlanta', 'and', 'fulton'): 1,
#          ('and', 'fulton', 'county'): 1,
#          ('fulton', 'county', 'purchasing'): 1,
#          ('county', 'purchasing', 'departments'): 1,
#          ('purchasing', 'departments', 'which'): 1,
#          ('departments', 'which', 'it'): 1,
#          ('which', 'it', 'said'): 1,
#          ('it', 'said', '``'): 1,
#          ('said', '``', 'are'): 1,
#          ('``', 'are', 'well'): 1,
#          ('are', 'well', 'operated'): 1,
#          ('well', 'operated', 'and'): 1,
#          ('operated', 'and', 'follow'): 1,
#          ('and', 'follow', 'generally'): 1,
#          ('follow', 'generally', 'accepted'): 1,
#          ('generally', 'accepted', 'practices'): 1,
#          ('accepted', 'practices', 'which'): 1,
#          ('practices', 'which', 'UNK'): 1,
#          ('which', 'UNK', 'to'): 1,
#          ('UNK', 'to', 'the'): 4,
#          ('to', 'the', 'best'): 1,
#          ('the', 'best', 'interest'): 1,
#          ('best', 'interest', 'of'): 1,
#          ('interest', 'of', 'both'): 1,
#          ('of', 'both', 'governments'): 1,
#          ('both', 'governments', "''"): 1,
#          ('governments', "''", '.'): 1,
#          ('START', 'START', 'however'): 1,
#          ('START', 'however', ','): 1,
#          ('however', ',', 'the'): 2,
#          ('said', 'it', 'believes'): 1,
#          ('it', 'believes', '``'): 1,
#          ('believes', '``', 'these'): 1,
#          ('``', 'these', 'two'): 1,
#          ('these', 'two', 'offices'): 1,
#          ('two', 'offices', 'should'): 1,
#          ('offices', 'should', 'be'): 1,
#          ('should', 'be', 'combined'): 1,
#          ('be', 'combined', 'to'): 1,
#          ('combined', 'to', 'achieve'): 1,
#          ('to', 'achieve', 'greater'): 1,
#          ('achieve', 'greater', 'efficiency'): 1,
#          ('greater', 'efficiency', 'and'): 1,
#          ('efficiency', 'and', 'reduce'): 1,
#          ('and', 'reduce', 'the'): 1,
#          ('reduce', 'the', 'cost'): 1,
#          ('the', 'cost', 'of'): 2,
#          ('cost', 'of', 'administration'): 1,
#          ('of', 'administration', "''"): 1,
#          ('administration', "''", '.'): 1,
#          ('START', 'the', 'city'): 5,
#          ('the', 'city', 'purchasing'): 1,
#          ('city', 'purchasing', 'department'): 1,
#          ('purchasing', 'department', ','): 1,
#          ('department', ',', 'the'): 2,
#          (',', '``', 'is'): 1,
#          ('``', 'is', 'lacking'): 1,
#          ('is', 'lacking', 'in'): 1,
#          ('lacking', 'in', 'experienced'): 1,
#          ('in', 'experienced', 'clerical'): 1,
#          ('experienced', 'clerical', 'personnel'): 1,
#          ('clerical', 'personnel', 'as'): 1,
#          ('personnel', 'as', 'a'): 1,
#          ('as', 'a', 'result'): 4,
#          ('a', 'result', 'of'): 2,
#          ('result', 'of', 'city'): 1,
#          ('of', 'city', 'personnel'): 1,
#          ('city', 'personnel', 'policies'): 1,
#          ('personnel', 'policies', "''"): 1,
#          ('policies', "''", '.'): 1,
#          ('START', 'it', 'urged'): 2,
#          ('it', 'urged', 'that'): 2,
#          ('urged', 'that', 'the'): 2,
#          ('the', 'city', '``'): 1,
#          ('city', '``', 'take'): 1,
#          ('``', 'take', 'steps'): 1,
#          ('take', 'steps', 'to'): 2,
#          ('steps', 'to', 'remedy'): 1,
#          ('to', 'remedy', "''"): 1,
#          ('remedy', "''", 'this'): 1,
#          ("''", 'this', 'problem'): 1,
#          ('this', 'problem', '.'): 1,
#          ('problem', '.', 'STOP'): 3,
#          ('START', 'START', 'implementation'): 1,
#          ('START', 'implementation', 'of'): 1,
#          ('implementation', 'of', 'georgia'): 1,
#          ('georgia', "'s", 'automobile'): 1,
#          ("'s", 'automobile', 'title'): 1,
#          ('automobile', 'title', 'law'): 1,
#          ('title', 'law', 'was'): 1,
#          ('law', 'was', 'also'): 1,
#          ('was', 'also', 'recommended'): 1,
#          ('also', 'recommended', 'by'): 1,
#          ('recommended', 'by', 'the'): 1,
#          ('by', 'the', 'outgoing'): 1,
#          ('the', 'outgoing', 'jury'): 1,
#          ('outgoing', 'jury', '.'): 1,
#          ('jury', '.', 'STOP'): 2,
#          ('that', 'the', 'next'): 2,
#          ('the', 'next', 'legislature'): 1,
#          ('next', 'legislature', '``'): 1,
#          ('legislature', '``', 'provide'): 1,
#          ('``', 'provide', 'enabling'): 1,
#          ('provide', 'enabling', 'funds'): 1,
#          ('enabling', 'funds', 'and'): 1,
#          ('funds', 'and', 'UNK'): 1,
#          ('and', 'UNK', 'the'): 1,
#          ('UNK', 'the', 'effective'): 1,
#          ('the', 'effective', 'date'): 1,
#          ('effective', 'date', 'so'): 1,
#          ('date', 'so', 'that'): 1,
#          ('so', 'that', 'an'): 1,
#          ('that', 'an', 'orderly'): 1,
#          ('an', 'orderly', 'implementation'): 1,
#          ('orderly', 'implementation', 'of'): 1,
#          ('implementation', 'of', 'the'): 1,
#          ('of', 'the', 'law'): 1,
#          ('the', 'law', 'may'): 1,
#          ('law', 'may', 'be'): 1,
#          ('may', 'be', 'effected'): 1,
#          ('be', 'effected', "''"): 1,
#          ('effected', "''", '.'): 1,
#          ('grand', 'jury', 'took'): 1,
#          ('jury', 'took', 'a'): 1,
#          ('took', 'a', 'swipe'): 1,
#          ('a', 'swipe', 'at'): 1,
#          ('swipe', 'at', 'the'): 1,
#          ('at', 'the', 'state'): 1,
#          ('the', 'state', 'welfare'): 2,
#          ('state', 'welfare', 'department'): 2,
#          ('welfare', 'department', "'s"): 1,
#          ('department', "'s", 'handling'): 1,
#          ("'s", 'handling', 'of'): 1,
#          ('handling', 'of', 'federal'): 1,
#          ('of', 'federal', 'funds'): 1,
#          ('federal', 'funds', 'granted'): 1,
#          ('funds', 'granted', 'for'): 1,
#          ('granted', 'for', 'child'): 1,
#          ('for', 'child', 'welfare'): 1,
#          ('child', 'welfare', 'services'): 1,
#          ('welfare', 'services', 'in'): 1,
#          ('services', 'in', 'foster'): 1,
#          ('in', 'foster', 'homes'): 1,
#          ('foster', 'homes', '.'): 1,
#          ('homes', '.', 'STOP'): 2,
#          ('START', '``', 'this'): 6,
#          ('``', 'this', 'is'): 5,
#          ('this', 'is', 'one'): 1,
#          ('is', 'one', 'of'): 3,
#          ('one', 'of', 'the'): 10,
#          ('of', 'the', 'major'): 1,
#          ('the', 'major', 'items'): 1,
#          ('major', 'items', 'in'): 1,
#          ('items', 'in', 'the'): 1,
#          ('in', 'the', 'fulton'): 1,
#          ('fulton', 'county', 'general'): 1,
#          ('county', 'general', 'assistance'): 1,
#          ('general', 'assistance', 'program'): 1,
#          ('assistance', 'program', "''"): 1,
#          ('program', "''", ','): 1,
#          ('said', ',', 'but'): 1,
#          (',', 'but', 'the'): 3,
#          ('but', 'the', 'state'): 1,
#          ('welfare', 'department', '``'): 1,
#          ('department', '``', 'has'): 1,
#          ('``', 'has', 'seen'): 1,
#          ('has', 'seen', 'fit'): 1,
#          ('seen', 'fit', 'to'): 1,
#          ('fit', 'to', 'distribute'): 1,
#          ('to', 'distribute', 'these'): 1,
#          ('distribute', 'these', 'funds'): 1,
#          ('these', 'funds', 'through'): 1,
#          ('funds', 'through', 'the'): 1,
#          ('through', 'the', 'welfare'): 1,
#          ('the', 'welfare', 'departments'): 1,
#          ('welfare', 'departments', 'of'): 1,
#          ('departments', 'of', 'all'): 1,
#          ('of', 'all', 'the'): 1,
#          ('all', 'the', 'counties'): 1,
#          ('the', 'counties', 'in'): 1,
#          ('counties', 'in', 'the'): 2,
#          ('in', 'the', 'state'): 9,
#          ('the', 'state', 'with'): 1,
#          ('state', 'with', 'the'): 1,
#          ('with', 'the', 'exception'): 1,
#          ('the', 'exception', 'of'): 1,
#          ('exception', 'of', 'fulton'): 1,
#          ('of', 'fulton', 'county'): 1,
#          ('fulton', 'county', ','): 1,
#          ('county', ',', 'which'): 1,
#          (',', 'which', 'receives'): 1,
#          ('which', 'receives', 'none'): 1,
#          ('receives', 'none', 'of'): 1,
#          ('none', 'of', 'this'): 1,
#          ('of', 'this', 'money'): 1,
#          ('this', 'money', '.'): 1,
#          ('money', '.', 'STOP'): 1,
#          ('START', 'the', 'jurors'): 1,
#          ('the', 'jurors', 'said'): 2,
#          ('jurors', 'said', 'they'): 1,
#          ('said', 'they', 'realize'): 1,
#          ('they', 'realize', '``'): 1,
#          ('realize', '``', 'a'): 1,
#          ('``', 'a', 'proportionate'): 1,
#          ('a', 'proportionate', 'distribution'): 1,
#          ('proportionate', 'distribution', 'of'): 1,
#          ('distribution', 'of', 'these'): 1,
#          ('of', 'these', 'funds'): 1,
#          ('these', 'funds', 'might'): 1,
#          ('funds', 'might', 'UNK'): 1,
#          ('might', 'UNK', 'this'): 1,
#          ('UNK', 'this', 'program'): 1,
#          ('this', 'program', 'in'): 1,
#          ('program', 'in', 'our'): 1,
#          ('in', 'our', 'less'): 1,
#          ('our', 'less', 'populous'): 1,
#          ('less', 'populous', 'counties'): 1,
#          ('populous', 'counties', "''"): 1,
#          ('counties', "''", '.'): 1,
#          ('START', 'START', 'nevertheless'): 1,
#          ('START', 'nevertheless', ','): 1,
#          ('nevertheless', ',', '``'): 1,
#          (',', '``', 'we'): 4,
#          ('``', 'we', 'feel'): 1,
#          ('we', 'feel', 'that'): 1,
#          ('feel', 'that', 'in'): 1,
#          ('that', 'in', 'the'): 2,
#          ('in', 'the', 'future'): 3,
#          ('the', 'future', 'fulton'): 1,
#          ('future', 'fulton', 'county'): 1,
#          ('fulton', 'county', 'should'): 1,
#          ('county', 'should', 'receive'): 1,
#          ('should', 'receive', 'some'): 1,
#          ('receive', 'some', 'portion'): 1,
#          ('some', 'portion', 'of'): 1,
#          ('portion', 'of', 'these'): 1,
#          ('of', 'these', 'available'): 1,
#          ('these', 'available', 'funds'): 1,
#          ('available', 'funds', "''"): 1,
#          ('funds', "''", ','): 2,
#          (',', 'the', 'jurors'): 1,
#          ('jurors', 'said', '.'): 1,
#          ('said', '.', 'STOP'): 36,
#          ('START', '``', 'failure'): 1,
#          ('``', 'failure', 'to'): 1,
#          ('failure', 'to', 'do'): 1,
#          ('to', 'do', 'this'): 1,
#          ('do', 'this', 'will'): 1,
#          ('this', 'will', 'continue'): 1,
#          ('will', 'continue', 'to'): 1,
#          ('continue', 'to', 'place'): 1,
#          ('to', 'place', 'a'): 1,
#          ('place', 'a', 'disproportionate'): 1,
#          ('a', 'disproportionate', 'burden'): 1,
#          ('disproportionate', 'burden', "''"): 1,
#          ('burden', "''", 'on'): 1,
#          ("''", 'on', 'fulton'): 1,
#          ('on', 'fulton', 'taxpayers'): 1,
#          ('fulton', 'taxpayers', '.'): 1,
#          ('taxpayers', '.', 'STOP'): 1,
#          ('the', 'jury', 'also'): 1,
#          ('jury', 'also', 'commented'): 1,
#          ('also', 'commented', 'on'): 1,
#          ('commented', 'on', 'the'): 1,
#          ('on', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'ordinary'): 1,
#          ('fulton', 'ordinary', "'s"): 1,
#          ('ordinary', "'s", 'court'): 1,
#          ("'s", 'court', 'which'): 1,
#          ('court', 'which', 'has'): 1,
#          ('which', 'has', 'been'): 2,
#          ('has', 'been', 'under'): 1,
#          ('been', 'under', 'fire'): 1,
#          ('under', 'fire', 'for'): 1,
#          ('fire', 'for', 'its'): 1,
#          ('for', 'its', 'practices'): 1,
#          ('its', 'practices', 'in'): 1,
#          ('practices', 'in', 'the'): 1,
#          ('in', 'the', 'appointment'): 1,
#          ('the', 'appointment', 'of'): 3,
#          ('appointment', 'of', 'UNK'): 1,
#          ('of', 'UNK', ','): 6,
#          ('UNK', ',', 'guardians'): 1,
#          (',', 'guardians', 'and'): 1,
#          ('guardians', 'and', 'administrators'): 1,
#          ('and', 'administrators', 'and'): 1,
#          ('administrators', 'and', 'the'): 1,
#          ('and', 'the', 'awarding'): 1,
#          ('the', 'awarding', 'of'): 1,
#          ('awarding', 'of', 'fees'): 1,
#          ('of', 'fees', 'and'): 1,
#          ('fees', 'and', 'compensation'): 1,
#          ('and', 'compensation', '.'): 1,
#          ('compensation', '.', 'STOP'): 1,
#          ('said', 'it', 'found'): 1,
#          ('it', 'found', 'the'): 1,
#          ('found', 'the', 'court'): 1,
#          ('the', 'court', '``'): 1,
#          ('court', '``', 'has'): 1,
#          ('``', 'has', 'incorporated'): 1,
#          ('has', 'incorporated', 'into'): 1,
#          ('incorporated', 'into', 'its'): 1,
#          ('into', 'its', 'operating'): 1,
#          ('its', 'operating', 'procedures'): 1,
#          ('operating', 'procedures', 'the'): 1,
#          ('procedures', 'the', 'recommendations'): 1,
#          ('the', 'recommendations', "''"): 1,
#          ('recommendations', "''", 'of'): 1,
#          ("''", 'of', 'two'): 1,
#          ('of', 'two', 'previous'): 1,
#          ('two', 'previous', 'grand'): 1,
#          ('previous', 'grand', 'UNK'): 1,
#          ('grand', 'UNK', ','): 1,
#          ('UNK', ',', 'the'): 4,
#          (',', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'bar'): 1,
#          ('atlanta', 'bar', 'association'): 1,
#          ('bar', 'association', 'and'): 1,
#          ('association', 'and', 'an'): 1,
#          ('and', 'an', 'interim'): 1,
#          ('an', 'interim', 'citizens'): 1,
#          ('interim', 'citizens', 'committee'): 1,
#          ('citizens', 'committee', '.'): 1,
#          ('committee', '.', 'STOP'): 10,
#          ('START', '``', 'these'): 1,
#          ('``', 'these', 'actions'): 1,
#          ('these', 'actions', 'should'): 1,
#          ('actions', 'should', 'serve'): 1,
#          ('should', 'serve', 'to'): 1,
#          ('serve', 'to', 'protect'): 1,
#          ('to', 'protect', 'in'): 1,
#          ('protect', 'in', 'fact'): 1,
#          ('in', 'fact', 'and'): 1,
#          ('fact', 'and', 'in'): 1,
#          ('and', 'in', 'effect'): 1,
#          ('in', 'effect', 'the'): 1,
#          ('effect', 'the', 'court'): 1,
#          ('the', 'court', "'s"): 1,
#          ('court', "'s", 'wards'): 1,
#          ("'s", 'wards', 'from'): 1,
#          ('wards', 'from', 'undue'): 1,
#          ('from', 'undue', 'costs'): 1,
#          ('undue', 'costs', 'and'): 1,
#          ('costs', 'and', 'its'): 1,
#          ('and', 'its', 'appointed'): 1,
#          ('its', 'appointed', 'and'): 1,
#          ('appointed', 'and', 'elected'): 1,
#          ('and', 'elected', 'servants'): 1,
#          ('elected', 'servants', 'from'): 1,
#          ('servants', 'from', 'UNK'): 1,
#          ('from', 'UNK', 'criticisms'): 1,
#          ('UNK', 'criticisms', "''"): 1,
#          ('criticisms', "''", ','): 1,
#          ('jury', 'said', '.'): 1,
#          ('START', 'START', 'regarding'): 1,
#          ('START', 'regarding', 'atlanta'): 1,
#          ('regarding', 'atlanta', "'s"): 1,
#          ('atlanta', "'s", 'new'): 1,
#          ("'s", 'new', 'multi-million-dollar'): 1,
#          ('new', 'multi-million-dollar', 'airport'): 1,
#          ('multi-million-dollar', 'airport', ','): 1,
#          ('airport', ',', 'the'): 1,
#          ('the', 'jury', 'recommended'): 2,
#          ('jury', 'recommended', '``'): 1,
#          ('recommended', '``', 'that'): 1,
#          ('``', 'that', 'when'): 1,
#          ('that', 'when', 'the'): 1,
#          ('when', 'the', 'new'): 1,
#          ('the', 'new', 'management'): 1,
#          ('new', 'management', 'takes'): 1,
#          ('management', 'takes', 'charge'): 1,
#          ('takes', 'charge', 'jan'): 1,
#          ('charge', 'jan', '&'): 1,
#          ('jan', '&', '1'): 3,
#          ('&', '1', 'the'): 1,
#          ('1', 'the', 'airport'): 1,
#          ('the', 'airport', 'be'): 1,
#          ('airport', 'be', 'operated'): 1,
#          ('be', 'operated', 'in'): 1,
#          ('operated', 'in', 'a'): 1,
#          ('in', 'a', 'manner'): 1,
#          ('a', 'manner', 'that'): 1,
#          ('manner', 'that', 'will'): 1,
#          ('that', 'will', 'eliminate'): 1,
#          ('will', 'eliminate', 'political'): 1,
#          ('eliminate', 'political', 'influences'): 1,
#          ('political', 'influences', "''"): 1,
#          ('influences', "''", '.'): 1,
#          ('the', 'jury', 'did'): 1,
#          ('jury', 'did', 'not'): 1,
#          ('did', 'not', 'elaborate'): 1,
#          ('not', 'elaborate', ','): 1,
#          ('elaborate', ',', 'but'): 1,
#          (',', 'but', 'it'): 1,
#          ('but', 'it', 'added'): 1,
#          ('it', 'added', 'that'): 1,
#          ('added', 'that', '``'): 1,
#          ('that', '``', 'there'): 1,
#          ('``', 'there', 'should'): 1,
#          ('there', 'should', 'be'): 2,
#          ('should', 'be', 'periodic'): 1,
#          ('be', 'periodic', 'surveillance'): 1,
#          ('periodic', 'surveillance', 'of'): 1,
#          ('surveillance', 'of', 'the'): 1,
#          ('of', 'the', 'pricing'): 1,
#          ('the', 'pricing', 'practices'): 1,
#          ('pricing', 'practices', 'of'): 1,
#          ('practices', 'of', 'the'): 1,
#          ('of', 'the', 'concessionaires'): 1,
#          ('the', 'concessionaires', 'for'): 1,
#          ('concessionaires', 'for', 'the'): 1,
#          ('for', 'the', 'purpose'): 1,
#          ('the', 'purpose', 'of'): 1,
#          ('purpose', 'of', 'keeping'): 1,
#          ('of', 'keeping', 'the'): 1,
#          ('keeping', 'the', 'prices'): 1,
#          ('the', 'prices', 'reasonable'): 1,
#          ('prices', 'reasonable', "''"): 1,
#          ('reasonable', "''", '.'): 1,
#          ('START', 'START', 'on'): 4,
#          ('START', 'on', 'other'): 1,
#          ('on', 'other', 'matters'): 1,
#          ('other', 'matters', ','): 1,
#          ('matters', ',', 'the'): 1,
#          ('jury', 'recommended', 'that'): 1,
#          ('recommended', 'that', ':'): 1,
#          ('that', ':', '_'): 1,
#          (':', '_', '-lrb-'): 1,
#          ('_', '-lrb-', '1'): 1,
#          ('-lrb-', '1', '-rrb-'): 1,
#          ('1', '-rrb-', '_'): 1,
#          ('-rrb-', '_', 'four'): 1,
#          ('_', 'four', 'additional'): 1,
#          ('four', 'additional', 'deputies'): 1,
#          ('additional', 'deputies', 'be'): 1,
#          ('deputies', 'be', 'employed'): 1,
#          ('be', 'employed', 'at'): 1,
#          ('employed', 'at', 'the'): 1,
#          ('at', 'the', 'fulton'): 1,
#          ('fulton', 'county', 'jail'): 1,
#          ('county', 'jail', 'and'): 1,
#          ('jail', 'and', '``'): 1,
#          ('and', '``', 'a'): 1,
#          ('``', 'a', 'doctor'): 1,
#          ('a', 'doctor', ','): 1,
#          ('doctor', ',', 'medical'): 1,
#          (',', 'medical', 'UNK'): 1,
#          ('medical', 'UNK', 'or'): 1,
#          ('UNK', 'or', 'UNK'): 1,
#          ('or', 'UNK', 'be'): 1,
#          ('UNK', 'be', 'employed'): 1,
#          ('be', 'employed', 'for'): 1,
#          ('employed', 'for', 'night'): 1,
#          ('for', 'night', 'and'): 1,
#          ('night', 'and', 'weekend'): 1,
#          ('and', 'weekend', 'duty'): 1,
#          ('weekend', 'duty', 'at'): 1,
#          ('duty', 'at', 'the'): 1,
#          ('at', 'the', 'jail'): 1,
#          ('the', 'jail', "''"): 1,
#          ('jail', "''", '.'): 1,
#          ('START', 'START', '_'): 47,
#          ('START', '_', '-lrb-'): 1,
#          ('_', '-lrb-', '2'): 1,
#          ('-lrb-', '2', '-rrb-'): 1,
#          ('2', '-rrb-', '_'): 1,
#          ('-rrb-', '_', 'fulton'): 1,
#          ('_', 'fulton', 'legislators'): 1,
#          ('fulton', 'legislators', '``'): 1,
#          ('legislators', '``', 'work'): 1,
#          ('``', 'work', 'with'): 1,
#          ('work', 'with', 'city'): 1,
#          ('with', 'city', 'officials'): 1,
#          ('city', 'officials', 'to'): 1,
#          ('officials', 'to', 'pass'): 1,
#          ('to', 'pass', 'enabling'): 1,
#          ('pass', 'enabling', 'legislation'): 1,
#          ('enabling', 'legislation', 'that'): 1,
#          ('legislation', 'that', 'will'): 1,
#          ('that', 'will', 'permit'): 1,
#          ('will', 'permit', 'the'): 1,
#          ('permit', 'the', 'establishment'): 1,
#          ('the', 'establishment', 'of'): 1,
#          ('establishment', 'of', 'a'): 2,
#          ('of', 'a', 'fair'): 1,
#          ('a', 'fair', 'and'): 1,
#          ('fair', 'and', 'equitable'): 1,
#          ('and', 'equitable', "''"): 1,
#          ('equitable', "''", 'pension'): 1,
#          ("''", 'pension', 'plan'): 1,
#          ('pension', 'plan', 'for'): 1,
#          ('plan', 'for', 'city'): 1,
#          ('for', 'city', 'employes'): 1,
#          ('city', 'employes', '.'): 1,
#          ('employes', '.', 'STOP'): 1,
#          ('the', 'jury', 'praised'): 1,
#          ('jury', 'praised', 'the'): 1,
#          ('praised', 'the', 'administration'): 1,
#          ('the', 'administration', 'and'): 1,
#          ('administration', 'and', 'operation'): 1,
#          ('and', 'operation', 'of'): 2,
#          ('operation', 'of', 'the'): 2,
#          ('of', 'the', 'atlanta'): 1,
#          ('the', 'atlanta', 'police'): 1,
#          ('atlanta', 'police', 'department'): 1,
#          ('police', 'department', ','): 1,
#          (',', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'tax'): 1,
#          ('fulton', 'tax', 'commissioner'): 1,
#          ('tax', 'commissioner', "'s"): 1,
#          ('commissioner', "'s", 'office'): 1,
#          ("'s", 'office', ','): 1,
#          ('office', ',', 'the'): 1,
#          (',', 'the', 'UNK'): 4,
#          ('the', 'UNK', 'and'): 2,
#          ('UNK', 'and', 'UNK'): 1,
#          ('and', 'UNK', 'prison'): 1,
#          ('UNK', 'prison', 'farms'): 1,
#          ('prison', 'farms', ','): 1,
#          ('farms', ',', 'grady'): 1,
#          (',', 'grady', 'hospital'): 1,
#          ('grady', 'hospital', 'and'): 1,
#          ('hospital', 'and', 'the'): 1,
#          ('and', 'the', 'fulton'): 1,
#          ('the', 'fulton', 'health'): 1,
#          ('fulton', 'health', 'department'): 1,
#          ('health', 'department', '.'): 1,
#          ('department', '.', 'STOP'): 2,
#          ('START', 'START', 'mayor'): 1,
#          ('START', 'mayor', 'william'): 1,
#          ('mayor', 'william', 'b'): 1,
#          ('william', 'b', '&'): 1,
#          ('b', '&', 'hartsfield'): 1,
#          ('&', 'hartsfield', 'filed'): 1,
#          ('hartsfield', 'filed', 'suit'): 1,
#          ('filed', 'suit', 'for'): 1,
#          ('suit', 'for', 'divorce'): 1,
#          ('for', 'divorce', 'from'): 1,
#          ('divorce', 'from', 'his'): 1,
#          ('from', 'his', 'wife'): 1,
#          ('his', 'wife', ','): 1,
#          ('wife', ',', 'pearl'): 1,
#          (',', 'pearl', 'williams'): 1,
#          ('pearl', 'williams', 'hartsfield'): 1,
#          ('williams', 'hartsfield', ','): 1,
#          ('hartsfield', ',', 'in'): 1,
#          (',', 'in', 'fulton'): 1,
#          ('in', 'fulton', 'superior'): 1,
#          ('superior', 'court', 'friday'): 1,
#          ('court', 'friday', '.'): 1,
#          ('friday', '.', 'STOP'): 2,
#          ('START', 'START', 'his'): 11,
#          ('START', 'his', 'petition'): 1,
#          ('his', 'petition', 'charged'): 1,
#          ('petition', 'charged', 'mental'): 1,
#          ('charged', 'mental', 'cruelty'): 1,
#          ('mental', 'cruelty', '.'): 1,
#          ('cruelty', '.', 'STOP'): 1,
#          ('START', 'the', 'couple'): 1,
#          ('the', 'couple', 'was'): 1,
#          ('couple', 'was', 'married'): 1,
#          ('was', 'married', 'aug'): 1,
#          ('married', 'aug', '&'): 1,
#          ('aug', '&', '2'): 1,
#          ('&', '2', ','): 1,
#          ('2', ',', '1913'): 1,
#          (',', '1913', '.'): 1,
#          ('1913', '.', 'STOP'): 1,
#          ('START', 'START', 'they'): 11,
#          ('START', 'they', 'have'): 1,
#          ('they', 'have', 'a'): 1,
#          ('have', 'a', 'son'): 1,
#          ('a', 'son', ','): 1,
#          ('son', ',', 'william'): 1,
#          (',', 'william', 'berry'): 1,
#          ('william', 'berry', 'jr'): 1,
#          ('berry', 'jr', '&'): 1,
#          ('jr', '&', ','): 4,
#          ('&', ',', 'and'): 2,
#          (',', 'and', 'a'): 3,
#          ('and', 'a', 'daughter'): 1,
#          ('a', 'daughter', ','): 2,
#          ('daughter', ',', 'mrs'): 1,
#          (',', 'mrs', '&'): 1,
#          ('mrs', '&', 'j'): 1,
#          ('&', 'j', '&'): 4,
#          ('j', '&', 'm'): 1,
#          ('&', 'm', '&'): 7,
#          ('m', '&', 'UNK'): 3,
#          ('&', 'UNK', 'of'): 2,
#          ('UNK', 'of', 'griffin'): 1,
#          ('of', 'griffin', '.'): 1,
#          ('griffin', '.', 'STOP'): 2,
#          ('START', 'START', 'attorneys'): 1,
#          ('START', 'attorneys', 'for'): 1,
#          ('attorneys', 'for', 'the'): 1,
#          ('for', 'the', 'mayor'): 1,
#          ('the', 'mayor', 'said'): 2,
#          ('mayor', 'said', 'that'): 1,
#          ('said', 'that', 'an'): 1,
#          ('that', 'an', 'UNK'): 1,
#          ('an', 'UNK', 'property'): 1,
#          ('UNK', 'property', 'settlement'): 1,
#          ('property', 'settlement', 'has'): 1,
#          ('settlement', 'has', 'been'): 1,
#          ('has', 'been', 'agreed'): 1,
#          ('been', 'agreed', 'upon'): 1,
#          ('agreed', 'upon', '.'): 1,
#          ('upon', '.', 'STOP'): 1,
#          ('START', 'the', 'petition'): 2,
#          ('the', 'petition', 'listed'): 1,
#          ('petition', 'listed', 'the'): 1,
#          ('listed', 'the', 'mayor'): 1,
#          ('the', 'mayor', "'s"): 5,
#          ('mayor', "'s", 'occupation'): 1,
#          ("'s", 'occupation', 'as'): 1,
#          ('occupation', 'as', '``'): 1,
#          ('as', '``', 'attorney'): 1,
#          ('``', 'attorney', "''"): 1,
#          ('attorney', "''", 'and'): 1,
#          ("''", 'and', 'his'): 1,
#          ('and', 'his', 'age'): 1,
#          ('his', 'age', 'as'): 1,
#          ('age', 'as', '71'): 1,
#          ('as', '71', '.'): 1,
#          ('71', '.', 'STOP'): 1,
#          ('START', 'it', 'listed'): 1,
#          ('it', 'listed', 'his'): 1,
#          ('listed', 'his', 'wife'): 1,
#          ('his', 'wife', "'s"): 1,
#          ('wife', "'s", 'age'): 1,
#          ("'s", 'age', 'as'): 1,
#          ('age', 'as', '74'): 1,
#          ('as', '74', 'and'): 1,
#          ('74', 'and', 'place'): 1,
#          ('and', 'place', 'of'): 1,
#          ('place', 'of', 'birth'): 1,
#          ('of', 'birth', 'as'): 1,
#          ('birth', 'as', 'opelika'): 1,
#          ('as', 'opelika', ','): 1,
#          ('opelika', ',', 'ala'): 1,
#          (',', 'ala', '&'): 1,
#          ('ala', '&', '.'): 1,
#          ('the', 'petition', 'said'): 1,
#          ('petition', 'said', 'that'): 1,
#          ('said', 'that', 'the'): 5,
#          ('that', 'the', 'couple'): 1,
#          ('the', 'couple', 'has'): 1,
#          ('couple', 'has', 'not'): 1,
#          ('has', 'not', 'lived'): 1,
#          ('not', 'lived', 'together'): 1,
#          ('lived', 'together', 'as'): 1,
#          ('together', 'as', 'man'): 1,
#          ('as', 'man', 'and'): 1,
#          ('man', 'and', 'wife'): 1,
#          ('and', 'wife', 'for'): 1,
#          ('wife', 'for', 'more'): 1,
#          ('for', 'more', 'than'): 2,
#          ('more', 'than', 'a'): 3,
#          ('than', 'a', 'year'): 2,
#          ('a', 'year', '.'): 3,
#          ('year', '.', 'STOP'): 12,
#          ('START', 'the', 'hartsfield'): 1,
#          ('the', 'hartsfield', 'home'): 1,
#          ('hartsfield', 'home', 'is'): 1,
#          ('home', 'is', 'at'): 1,
#          ('is', 'at', 'UNK'): 1,
#          ('at', 'UNK', 'e'): 1,
#          ('UNK', 'e', '&'): 1,
#          ('e', '&', 'pelham'): 1,
#          ('&', 'pelham', 'rd'): 1,
#          ('pelham', 'rd', '&'): 1,
#          ('rd', '&', 'ne'): 1,
#          ('&', 'ne', '.'): 1,
#          ('ne', '.', 'STOP'): 1,
#          ('START', 'START', 'henry'): 1,
#          ('START', 'henry', 'l'): 1,
#          ('henry', 'l', '&'): 1,
#          ('l', '&', 'bowden'): 1,
#          ('&', 'bowden', 'was'): 1,
#          ('bowden', 'was', 'listed'): 1,
#          ('was', 'listed', 'on'): 1,
#          ('listed', 'on', 'the'): 2,
#          ('on', 'the', 'petition'): 1,
#          ('the', 'petition', 'as'): 1,
#          ('petition', 'as', 'the'): 1,
#          ('as', 'the', 'mayor'): 1,
#          ('mayor', "'s", 'attorney'): 1,
#          ("'s", 'attorney', '.'): 1,
#          ('attorney', '.', 'STOP'): 2,
#          ('START', 'START', 'hartsfield'): 1,
#          ('START', 'hartsfield', 'has'): 1,
#          ('hartsfield', 'has', 'been'): 1,
#          ('has', 'been', 'mayor'): 1,
#          ('been', 'mayor', 'of'): 1,
#          ('mayor', 'of', 'atlanta'): 1,
#          ('of', 'atlanta', ','): 1,
#          ('atlanta', ',', 'with'): 1,
#          (',', 'with', 'exception'): 1,
#          ('with', 'exception', 'of'): 1,
#          ('exception', 'of', 'one'): 1,
#          ('of', 'one', 'brief'): 1,
#          ('one', 'brief', 'interlude'): 1,
#          ('brief', 'interlude', ','): 1,
#          ('interlude', ',', 'since'): 1,
#          (',', 'since', '1937'): 1,
#          ('since', '1937', '.'): 1,
#          ('1937', '.', 'STOP'): 1,
#          ('START', 'his', 'political'): 1,
#          ('his', 'political', 'career'): 1,
#          ('political', 'career', 'goes'): 1,
#          ('career', 'goes', 'back'): 1,
#          ('goes', 'back', 'to'): 1,
#          ('back', 'to', 'his'): 1,
#          ('to', 'his', 'election'): 1,
#          ('his', 'election', 'to'): 1,
#          ('election', 'to', 'city'): 1,
#          ('to', 'city', 'council'): 1,
#          ('city', 'council', 'in'): 1,
#          ('council', 'in', '1923'): 1,
#          ('in', '1923', '.'): 1,
#          ('1923', '.', 'STOP'): 1,
#          ('START', 'the', 'mayor'): 4,
#          ('mayor', "'s", 'present'): 1,
#          ("'s", 'present', 'term'): 1,
#          ('present', 'term', 'of'): 1,
#          ('term', 'of', 'office'): 1,
#          ('of', 'office', 'UNK'): 1,
#          ('office', 'UNK', 'jan'): 1,
#          ('UNK', 'jan', '&'): 1,
#          ('&', '1', '.'): 1,
#          ('1', '.', 'STOP'): 4,
#          ('START', 'START', 'he'): 63,
#          ('START', 'he', 'will'): 5,
#          ('he', 'will', 'be'): 2,
#          ('will', 'be', 'succeeded'): 2,
#          ('be', 'succeeded', 'by'): 2,
#          ('succeeded', 'by', 'ivan'): 1,
#          ('by', 'ivan', 'allen'): 1,
#          ('&', ',', 'who'): 1,
#          (',', 'who', 'became'): 1,
#          ('who', 'became', 'a'): 1,
#          ('became', 'a', 'candidate'): 1,
#          ('a', 'candidate', 'in'): 3,
#          ('candidate', 'in', 'the'): 2,
#          ('in', 'the', 'sept'): 2,
#          ('the', 'sept', '&'): 2,
#          ('sept', '&', '13'): 1,
#          ('&', '13', 'primary'): 1,
#          ('13', 'primary', 'after'): 1,
#          ('primary', 'after', 'mayor'): 1,
#          ('after', 'mayor', 'hartsfield'): 1,
#          ('mayor', 'hartsfield', 'announced'): 1,
#          ('hartsfield', 'announced', 'that'): 1,
#          ('announced', 'that', 'he'): 1,
#          ('that', 'he', 'would'): 3,
#          ('he', 'would', 'not'): 2,
#          ('would', 'not', 'run'): 1,
#          ('not', 'run', 'for'): 1,
#          ('run', 'for', 'reelection'): 1,
#          ('for', 'reelection', '.'): 1,
#          ('reelection', '.', 'STOP'): 1,
#          ('START', 'START', 'georgia'): 1,
#          ('START', 'georgia', 'republicans'): 1,
#          ('georgia', 'republicans', 'are'): 1,
#          ('republicans', 'are', 'getting'): 1,
#          ('are', 'getting', 'strong'): 1,
#          ('getting', 'strong', 'encouragement'): 1,
#          ('strong', 'encouragement', 'to'): 1,
#          ('encouragement', 'to', 'enter'): 1,
#          ('to', 'enter', 'a'): 2,
#          ('enter', 'a', 'candidate'): 2,
#          ('in', 'the', '1962'): 1,
#          ('the', '1962', 'governor'): 1,
#          ('1962', 'governor', "'s"): 1,
#          ('governor', "'s", 'race'): 1,
#          ("'s", 'race', ','): 1,
#          ('race', ',', 'a'): 1,
#          (',', 'a', 'top'): 1,
#          ('a', 'top', 'official'): 1,
#          ('top', 'official', 'said'): 1,
#          ('official', 'said', 'wednesday'): 1,
#          ('said', 'wednesday', '.'): 1,
#          ('wednesday', '.', 'STOP'): 2,
#          ('START', 'START', 'robert'): 1,
#          ('START', 'robert', 'snodgrass'): 1,
#          ('robert', 'snodgrass', ','): 1,
#          ('snodgrass', ',', 'state'): 1,
#          (',', 'state', 'gop'): 1,
#          ('state', 'gop', 'chairman'): 1,
#          ('gop', 'chairman', ','): 1,
#          ('chairman', ',', 'said'): 1,
#          (',', 'said', 'a'): 2,
#          ('said', 'a', 'meeting'): 1,
#          ('a', 'meeting', 'held'): 1,
#          ('meeting', 'held', 'tuesday'): 1,
#          ...})

# %%
# Out:
# CHECK TRIGRAM [('START', 'START', ('START', 'START', 'the')), ('START', ('START', 'START', 'the'), ('START', 'the', 'fulton')), (('START', 'START', 'the'), ('START', 'the', 'fulton'), ('the', 'fulton', 'county')), (('START', 'the', 'fulton'), ('the', 'fulton', 'county'), ('fulton', 'county', 'grand')), (('the', 'fulton', 'county'), ('fulton', 'county', 'grand'), ('county', 'grand', 'jury')), (('fulton', 'county', 'grand'), ('county', 'grand', 'jury'), ('grand', 'jury', 'said')), (('county', 'grand', 'jury'), ('grand', 'jury', 'said'), ('jury', 'said', 'friday')), (('grand', 'jury', 'said'), ('jury', 'said', 'friday'), ('said', 'friday', 'an')), (('jury', 'said', 'friday'), ('said', 'friday', 'an'), ('friday', 'an', 'investigation')), (('said', 'friday', 'an'), ('friday', 'an', 'investigation'), ('an', 'investigation', 'of')), (('friday', 'an', 'investigation'), ('an', 'investigation', 'of'), ('investigation', 'of', 'atlanta')), (('an', 'investigation', 'of'), ('investigation', 'of', 'atlanta'), ('of', 'atlanta', "'s")), (('investigation', 'of', 'atlanta'), ('of', 'atlanta', "'s"), ('atlanta', "'s", 'recent')), (('of', 'atlanta', "'s"), ('atlanta', "'s", 'recent'), ("'s", 'recent', 'primary')), (('atlanta', "'s", 'recent'), ("'s", 'recent', 'primary'), ('recent', 'primary', 'election')), (("'s", 'recent', 'primary'), ('recent', 'primary', 'election'), ('primary', 'election', 'produced')), (('recent', 'primary', 'election'), ('primary', 'election', 'produced'), ('election', 'produced', '``')), (('primary', 'election', 'produced'), ('election', 'produced', '``'), ('produced', '``', 'no')), (('election', 'produced', '``'), ('produced', '``', 'no'), ('``', 'no', 'evidence')), (('produced', '``', 'no'), ('``', 'no', 'evidence'), ('no', 'evidence', "''")), (('``', 'no', 'evidence'), ('no', 'evidence', "''"), ('evidence', "''", 'that')), (('no', 'evidence', "''"), ('evidence', "''", 'that'), ("''", 'that', 'any')), (('evidence', "''", 'that'), ("''", 'that', 'any'), ('that', 'any', 'irregularities')), (("''", 'that', 'any'), ('that', 'any', 'irregularities'), ('any', 'irregularities', 'took')), (('that', 'any', 'irregularities'), ('any', 'irregularities', 'took'), ('irregularities', 'took', 'place')), (('any', 'irregularities', 'took'), ('irregularities', 'took', 'place'), ('took', 'place', '.')), (('irregularities', 'took', 'place'), ('took', 'place', '.'), ('place', '.', 'STOP')), (('took', 'place', '.'), ('place', '.', 'STOP'), 'STOP')]
# trigram got is ('START', 'START', ('START', 'START', 'the'))
# trigram got is ('START', ('START', 'START', 'the'), ('START', 'the', 'fulton'))
# trigram got is (('START', 'START', 'the'), ('START', 'the', 'fulton'), ('the', 'fulton', 'county'))
# trigram got is (('START', 'the', 'fulton'), ('the', 'fulton', 'county'), ('fulton', 'county', 'grand'))
# trigram got is (('the', 'fulton', 'county'), ('fulton', 'county', 'grand'), ('county', 'grand', 'jury'))
# trigram got is (('fulton', 'county', 'grand'), ('county', 'grand', 'jury'), ('grand', 'jury', 'said'))
# trigram got is (('county', 'grand', 'jury'), ('grand', 'jury', 'said'), ('jury', 'said', 'friday'))
# trigram got is (('grand', 'jury', 'said'), ('jury', 'said', 'friday'), ('said', 'friday', 'an'))
# trigram got is (('jury', 'said', 'friday'), ('said', 'friday', 'an'), ('friday', 'an', 'investigation'))
# trigram got is (('said', 'friday', 'an'), ('friday', 'an', 'investigation'), ('an', 'investigation', 'of'))
# trigram got is (('friday', 'an', 'investigation'), ('an', 'investigation', 'of'), ('investigation', 'of', 'atlanta'))
# trigram got is (('an', 'investigation', 'of'), ('investigation', 'of', 'atlanta'), ('of', 'atlanta', "'s"))
# trigram got is (('investigation', 'of', 'atlanta'), ('of', 'atlanta', "'s"), ('atlanta', "'s", 'recent'))
# trigram got is (('of', 'atlanta', "'s"), ('atlanta', "'s", 'recent'), ("'s", 'recent', 'primary'))
# trigram got is (('atlanta', "'s", 'recent'), ("'s", 'recent', 'primary'), ('recent', 'primary', 'election'))
# trigram got is (("'s", 'recent', 'primary'), ('recent', 'primary', 'election'), ('primary', 'election', 'produced'))
# trigram got is (('recent', 'primary', 'election'), ('primary', 'election', 'produced'), ('election', 'produced', '``'))
# trigram got is (('primary', 'election', 'produced'), ('election', 'produced', '``'), ('produced', '``', 'no'))
# trigram got is (('election', 'produced', '``'), ('produced', '``', 'no'), ('``', 'no', 'evidence'))
# trigram got is (('produced', '``', 'no'), ('``', 'no', 'evidence'), ('no', 'evidence', "''"))
# trigram got is (('``', 'no', 'evidence'), ('no', 'evidence', "''"), ('evidence', "''", 'that'))
# trigram got is (('no', 'evidence', "''"), ('evidence', "''", 'that'), ("''", 'that', 'any'))
# trigram got is (('evidence', "''", 'that'), ("''", 'that', 'any'), ('that', 'any', 'irregularities'))
# trigram got is (("''", 'that', 'any'), ('that', 'any', 'irregularities'), ('any', 'irregularities', 'took'))
# trigram got is (('that', 'any', 'irregularities'), ('any', 'irregularities', 'took'), ('irregularities', 'took', 'place'))
# trigram got is (('any', 'irregularities', 'took'), ('irregularities', 'took', 'place'), ('took', 'place', '.'))
# trigram got is (('irregularities', 'took', 'place'), ('took', 'place', '.'), ('place', '.', 'STOP'))
# trigram got is (('took', 'place', '.'), ('place', '.', 'STOP'), 'STOP')
# 0

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amogh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.util import ngrams

# %%
text = "I am aware that nltk only offers bigrams and trigrams, but is there a way to split my text in four-grams, five-grams or even hundred-grams"
tokenize = nltk.word_tokenize(text)

# %%
tokenize = nltk.word_tokenize(text)

# %%
bigrams = list(ngrams(tokenize,1))
bigrams
# Out:
# [('I',),
#  ('am',),
#  ('aware',),
#  ('that',),
#  ('nltk',),
#  ('only',),
#  ('offers',),
#  ('bigrams',),
#  ('and',),
#  ('trigrams',),
#  (',',),
#  ('but',),
#  ('is',),
#  ('there',),
#  ('a',),
#  ('way',),
#  ('to',),
#  ('split',),
#  ('my',),
#  ('text',),
#  ('in',),
#  ('four-grams',),
#  (',',),
#  ('five-grams',),
#  ('or',),
#  ('even',),
#  ('hundred-grams',)]
